# %% [markdown]
# # Scraping Samsung from GSMArena

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
base_url = "https://www.gsmarena.com/results.php3?sMakers=9"
HEADERS = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/118.0.5993.118 Safari/537.36"
    )
}

# %%
r = requests.get(base_url,HEADERS)
r.raise_for_status()  
soup = BeautifulSoup(r.text, "html.parser")

# %%
row_divs = soup.find_all("div", class_="makers")
if row_divs:
    target_row = row_divs[0] 
else:
    print("Error: The 'makers' div was not found on the page.")
    target_row = None

if target_row:
    all_target_li = target_row.select("ul > li")
    first_30_li = all_target_li[:30]

    print(f"Total <li> elements found in the target <ul>: {len(all_target_li)}")
    print(f"Successfully selected the first {len(first_30_li)} list items.")
# Out:
# Total <li> elements found in the target <ul>: 70
# Successfully selected the first 30 list items.

# %%
print(first_30_li)
# Out:
# [<li><a href="samsung_galaxy_a56-13603.php"><img src="https://fdn2.gsmarena.com/vv/bigpic/samsung-galaxy-a56-.jpg" title="Samsung Galaxy A56 Android smartphone. Announced Mar 2025. Features 6.7″  display, Exynos 1580 chipset, 5000 mAh battery, 256 GB storage, 12 GB RAM, Corning Gorilla Glass Victus+."/><strong><span>Samsung<br/>Galaxy A56</span></strong></a></li>, <li><a href="samsung_galaxy_s25_ultra-13322.php"><img src="https://fdn2.gsmarena.com/vv/bigpic/samsung-galaxy-s25-ultra-sm-s938.jpg" title="Samsung Galaxy S25 Ultra Android smartphone. Announced Jan 2025. Features 6.9″  display, Snapdragon 8 Elite chipset, 5000 mAh battery, 1024 GB storage, 16 GB RAM, Corning Gorilla Armor 2."/><strong><span>Samsung<br/>Galaxy S25 Ultra</span></strong></a></li>, <li><a href="samsung_galaxy_a17_5g-14041.php"><img src="https://fdn2.gsmarena.com/vv/bigpic/samsung-galaxy-a17-5g.jpg" title="Samsung Galaxy A17 5G Android smartphone. Announced Aug 2025. Features 6.7″  display, Exynos 1330 chipset, 5000 mAh battery, 256 GB storage, 8 GB RAM, Corning Gorilla Glass Victus."/><strong><span>Samsung<br/>Galaxy A17</span></strong></a></li>, <li><a href="samsung_galaxy_s25-13610.php"><img src="https://fdn2.gsmarena.com/vv/bigpic/samsung-galaxy-s25-sm-s931.jpg" title="Samsung Galaxy S25 Android smartphone. Announced Jan 2025. Features 6.2″  display, Snapdragon 8 Elite chipset, 4000 mAh battery, 512 GB storage, 12 GB RAM, Corning Gorilla Glass Victus 2."/><strong><span>Samsung<br/>Galaxy S25</span></strong></a></li>, <li><a href="samsung_galaxy_a36-13497.php"><img src="https://fdn2.gsmarena.com/vv/bigpic/samsung-galaxy-a36.jpg" title="Samsung Galaxy A36 Android smartphone. Announced Mar 2025. Features 6.7″  display, Snapdragon 6 Gen 3 chipset, 5000 mAh battery, 256 GB storage, 12 GB RAM, Corning Gorilla Glass Victus+."/><strong><span>Samsung<br/>Galaxy A36</span></strong></a></li>, <li><a href="samsung_galaxy_s25_fe_5g-14042.php"><img src="https://fdn2.gsmarena.com/vv/bigpic/samsung-galaxy-s25-fe.jpg" title="Samsung Galaxy S25 FE 5G Android smartphone. Announced Sep 2025. Features 6.7″  display, Exynos 2400 chipset, 4900 mAh battery, 512 GB storage, 8 GB RAM, Corning Gorilla Glass Victus+."/><strong><span>Samsung<br/>Galaxy S25 FE</span></strong></a></li>, <li><a href="samsung_galaxy_a07-14066.php"><img src="https://fdn2.gsmarena.com/vv/bigpic/samsung-galaxy-a07.jpg" title="Samsung Galaxy A07 Android smartphone. Announced Aug 2025. Features 6.7″  display, Helio G99 chipset, 5000 mAh battery, 256 GB storage, 8 GB RAM."/><strong><span>Samsung<br/>Galaxy A07 4G</span></strong></a></li>, <li><a href="samsung_galaxy_s24_ultra-12771.php"><img src="https://fdn2.gsmarena.com/vv/bigpic/samsung-galaxy-s24-ultra-5g-sm-s928-stylus.jpg" title="Samsung Galaxy S24 Ultra Android smartphone. Announced Jan 2024. Features 6.8″  display, Snapdragon 8 Gen 3 chipset, 5000 mAh battery, 1024 GB storage, 12 GB RAM, Corning Gorilla Armor."/><strong><span>Samsung<br/>Galaxy S24 Ultra</span></strong></a></li>, <li><a href="samsung_galaxy_s24-12773.php"><img src="https://fdn2.gsmarena.com/vv/bigpic/samsung-galaxy-s24-5g-sm-s921.jpg" title="Samsung Galaxy S24 Android smartphone. Announced Jan 2024. Features 6.2″  display, Snapdragon 8 Gen 3 chipset, 4000 mAh battery, 512 GB storage, 12 GB RAM, Corning Gorilla Glass Victus 2."/><strong><span>Samsung<br/>Galaxy S24</span></strong></a></li>, <li><a href="samsung_galaxy_s24_fe-13262.php"><img src="https://fdn2.gsmarena.com/vv/bigpic/samsung-galaxy-s24-fe-r1.jpg" title="Samsung Galaxy S24 FE Android smartphone. Announced Sep 2024. Features 6.7″  display, Exynos 2400e chipset, 4700 mAh battery, 512 GB storage, 8 GB RAM, Corning Gorilla Glass Victus+."/><strong><span>Samsung<br/>Galaxy S24 FE</span></strong></a></li>, <li><a href="samsung_galaxy_a55-12824.php"><img src="https://fdn2.gsmarena.com/vv/bigpic/samsung-galaxy-a55.jpg" title="Samsung Galaxy A55 Android smartphone. Announced Mar 2024. Features 6.6″  display, Exynos 1480 chipset ...

# %%
new_base_url = "https://www.gsmarena.com/" 
scraped_data = []
for li_tag in first_30_li:
    link_tag = li_tag.find('a')
    name = link_tag.find('strong').get_text(strip=True).replace('\n', ' ')
    
    full_url = new_base_url + link_tag.get('href')
    
    scraped_data.append({
        'name': name, 
        'link': full_url 
    })

# %%
scraped_data
# Out:
# [{'name': 'SamsungGalaxy A56',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_a56-13603.php'},
#  {'name': 'SamsungGalaxy S25 Ultra',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s25_ultra-13322.php'},
#  {'name': 'SamsungGalaxy A17',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_a17_5g-14041.php'},
#  {'name': 'SamsungGalaxy S25',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s25-13610.php'},
#  {'name': 'SamsungGalaxy A36',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_a36-13497.php'},
#  {'name': 'SamsungGalaxy S25 FE',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s25_fe_5g-14042.php'},
#  {'name': 'SamsungGalaxy A07 4G',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_a07-14066.php'},
#  {'name': 'SamsungGalaxy S24 Ultra',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s24_ultra-12771.php'},
#  {'name': 'SamsungGalaxy S24',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s24-12773.php'},
#  {'name': 'SamsungGalaxy S24 FE',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s24_fe-13262.php'},
#  {'name': 'SamsungGalaxy A55',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_a55-12824.php'},
#  {'name': 'SamsungGalaxy A26',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_a26-13679.php'},
#  {'name': 'SamsungGalaxy A16 5G',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_a16_5g-13346.php'},
#  {'name': 'SamsungGalaxy S22 Ultra 5G',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s22_ultra_5g-11251.php'},
#  {'name': 'SamsungGalaxy A16',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_a16-13383.php'},
#  {'name': 'SamsungGalaxy A06',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_a06-13265.php'},
#  {'name': 'SamsungGalaxy S23 Ultra',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s23_ultra-12024.php'},
#  {'name': 'SamsungGalaxy A35',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_a35-12705.php'},
#  {'name': 'SamsungGalaxy S23',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s23-12082.php'},
#  {'name': 'SamsungGalaxy S22 5G',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s22_5g-11253.php'},
#  {'name': 'SamsungGalaxy S25 Edge',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s25_edge-13506.php'},
#  {'name': 'SamsungGalaxy Z Fold7',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_z_fold7-13826.php'},
#  {'name': 'SamsungGalaxy A15',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_a15-12637.php'},
#  {'name': 'SamsungGalaxy S21 5G',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s21_5g-10626.php'},
#  {'name': 'SamsungGalaxy S21 Ultra 5G',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s21_ultra_5g-10596.php'},
#  {'name': 'SamsungGalaxy A54',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_a54-12070.php'},
#  {'name': 'SamsungGalaxy M17',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_m17_5g-14221.php'},
#  {'name': 'SamsungGalaxy S25+',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s25+-13609.php'},
#  {'name': 'SamsungGalaxy S21 FE 5G',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s21_fe_5g-10954.php'},
#  {'name': 'SamsungGalaxy A05',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_a05-12583.php'}]

# %%
import time 
final_data = []

for item in scraped_data:
    url = item['link']
    
   
    try:
        r = requests.get(url, headers=HEADERS, timeout=10)
        r.raise_for_status()  
        soup = BeautifulSoup(r.text, "html.parser")
        specs_div = soup.find(id="specs-list") 
        specs_html = str(specs_div) if specs_div else "Specs list not found"
        
        final_data.append({
            'name': item['name'],
            'link': url,
            'specs_list_html': specs_html
        })
        
        
        time.sleep(2) 
        
    except requests.exceptions.RequestException as e:
        print(f"Failed to fetch {url}: {e}")
        final_data.append({
            'name': item['name'],
            'link': url,
            'specs_list_html': f"ERROR: Failed to fetch page - {e}"
        })


print(f"Finished scraping. Total items processed: {len(final_data)}")
# Out:
# Finished scraping. Total items processed: 30

# %%
final_data
# Out:
# [{'name': 'SamsungGalaxy A56',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_a56-13603.php',
#   'specs_list_html': '<div id="specs-list">\n<style type="text/css"> .tr-toggle {  display:none; }  </style>\n<table cellspacing="0">\n<tr class="tr-hover">\n<th rowspan="15" scope="row">Network</th>\n<td class="ttl"><a href="network-bands.php3">Technology</a></td>\n<td class="nfo"><a class="link-network-detail collapse" data-spec="nettech" href="#">GSM / HSPA / LTE / 5G</a></td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">2G bands</a></td>\n<td class="nfo" data-spec="net2g">GSM 850 / 900 / 1800 / 1900 </td>\n</tr><tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">3G bands</a></td>\n<td class="nfo" data-spec="net3g">HSDPA 850 / 900 / 1700(AWS) / 1900 / 2100 </td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">4G bands</a></td>\n<td class="nfo" data-spec="net4g">1, 2, 3, 4, 5, 7, 8, 12, 17, 20, 25, 26, 28, 32, 38, 40, 41, 66</td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">5G bands</a></td>\n<td class="nfo" data-spec="net5g">1, 3, 5, 7, 8, 20, 28, 38, 40, 41, 66, 77, 78 SA/NSA/Sub6</td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="glossary.php3?term=3g">Speed</a></td>\n<td class="nfo" data-spec="speed">HSPA, LTE, 5G</td>\n</tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="2" scope="row">Launch</th>\n<td class="ttl"><a href="glossary.php3?term=phone-life-cycle">Announced</a></td>\n<td class="nfo" data-spec="year">2025, March 02</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=phone-life-cycle">Status</a></td>\n<td class="nfo" data-spec="status">Available. Released 2025, March 10</td>\n</tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="6" scope="row">Body</th>\n<td class="ttl"><a href="#" onclick="helpW(\'h_dimens.htm\');">Dimensions</a></td>\n<td class="nfo" data-spec="dimensions">162.2 x 77.5 x 7.4 mm (6.39 x 3.05 x 0.29 in)</td>\n</tr><tr>\n<td class="ttl"><a href="#" onclick="helpW(\'h_weight.htm\');">Weight</a></td>\n<td class="nfo" data-spec="weight">198 g (6.98 oz)</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=build">Build</a></td>\n<td class="nfo" data-spec="build">Glass front (Gorilla Glass Victus+), glass back (Gorilla Glass Victus+), aluminum frame</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=sim">SIM</a></td>\n<td class="nfo" data-spec="sim">Nano-SIM + Nano-SIM + <a href="glossary.php3?term=esim">eSIM</a> + eSIM (max 2 at a time)</td>\n</tr>\n<tr><td class="ttl">\xa0</td><td class="nfo" data-spec="bodyother">IP67 dust/water resistant (up to 1m for 30 min)</td></tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="5" scope="row">Display</th>\n<td class="ttl"><a href="glossary.php3?term=display-type">Type</a></td>\n<td class="nfo" data-spec="displaytype">Super AMOLED, 120Hz, HDR10+, 1200 nits (HBM), 1900 nits (peak)</td>\n</tr>\n<tr>\n<td class="ttl"><a href="#" onclick="helpW(\'h_dsize.htm\');">Size</a></td>\n<td class="nfo" data-spec="displaysize">6.7 inches, 110.2 cm<sup>2</sup> (~87.7% screen-to-body ratio)</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=resolution">Resolution</a></td>\n<td class="nfo" data-spec="displayresolution">1080 x 2340 pixels, 19.5:9 ratio (~385 ppi density)</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=screen-protection">Protection</a></td>\n<td class="nfo" data-spec="displayprotection">Corning Gorilla Glass Victus+, Mohs level 5</td>\n</tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="4" scope="row">Platform</th>\n<td class="ttl"><a href="glossary.php3?term=os">OS</a></td>\n<td class="nfo" data-spec="os">Android 15, up to 6 major Android upgrades, One UI 7</td>\n</tr>\n<tr><td class="ttl"><a href="glossary.php3?term=chipset">Chipset</a></td>\n<td class="nfo" data-spec="chipset">Exynos 1580 (4 nm)</td>\n</tr>\n<tr><td class="ttl"><a href="glossary.php3?term=cpu">CPU</a></td>\n<td class="nfo" data-spec="cpu">Octa-core (1x2.9 GHz Cortex-A720 &amp; 3x2.6  ...
#  {'name': 'SamsungGalaxy S25 Ultra',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s25_ultra-13322.php',
#   'specs_list_html': '<div id="specs-list">\n<style type="text/css"> .tr-toggle {  display:none; }  </style>\n<table cellspacing="0">\n<tr class="tr-hover">\n<th rowspan="15" scope="row">Network</th>\n<td class="ttl"><a href="network-bands.php3">Technology</a></td>\n<td class="nfo"><a class="link-network-detail collapse" data-spec="nettech" href="#">GSM / CDMA / HSPA / EVDO / LTE / 5G</a></td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">2G bands</a></td>\n<td class="nfo" data-spec="net2g">GSM 850 / 900 / 1800 / 1900 </td>\n</tr><tr class="tr-toggle" data-spec-optional="">\n<td class="ttl">\xa0</td>\n<td class="nfo">CDMA 800 / 1900 &amp; TD-SCDMA</td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">3G bands</a></td>\n<td class="nfo" data-spec="net3g">HSDPA 850 / 900 / 1700(AWS) / 1900 / 2100 </td>\n</tr>\n<tr class="tr-toggle" data-spec-optional="">\n<td class="ttl">\xa0</td>\n<td class="nfo">CDMA2000 1xEV-DO </td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">4G bands</a></td>\n<td class="nfo" data-spec="net4g">1, 2, 3, 4, 5, 7, 8, 12, 13, 17, 18, 19, 20, 25, 26, 28, 32, 38, 39, 40, 41, 66 - International</td>\n</tr>\n<tr class="tr-toggle" data-spec-optional="">\n<td class="ttl">\xa0</td>\n<td class="nfo">1, 2, 3, 4, 5, 7, 8, 12, 13, 14, 18, 19, 20, 25, 26, 28, 29, 30, 38, 39, 40, 41, 48, 66, 71 - USA unlocked</td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">5G bands</a></td>\n<td class="nfo" data-spec="net5g">1, 2, 3, 5, 7, 8, 12, 20, 25, 26, 28, 38, 40, 41, 66, 75, 77, 78 SA/NSA/Sub6 - International</td>\n</tr>\n<tr class="tr-toggle" data-spec-optional="">\n<td class="ttl">\xa0</td>\n<td class="nfo">1, 2, 5, 7, 25, 28, 41, 66, 71, 77, 78, 257, 258, 260, 261 SA/NSA/Sub6/mmWave - USA unlocked</td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="glossary.php3?term=3g">Speed</a></td>\n<td class="nfo" data-spec="speed">HSPA, LTE (up to 7CA), 5G</td>\n</tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="2" scope="row">Launch</th>\n<td class="ttl"><a href="glossary.php3?term=phone-life-cycle">Announced</a></td>\n<td class="nfo" data-spec="year">2025, January 22</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=phone-life-cycle">Status</a></td>\n<td class="nfo" data-spec="status">Available. Released 2025, February 03</td>\n</tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="6" scope="row">Body</th>\n<td class="ttl"><a href="#" onclick="helpW(\'h_dimens.htm\');">Dimensions</a></td>\n<td class="nfo" data-spec="dimensions">162.8 x 77.6 x 8.2 mm (6.41 x 3.06 x 0.32 in)</td>\n</tr><tr>\n<td class="ttl"><a href="#" onclick="helpW(\'h_weight.htm\');">Weight</a></td>\n<td class="nfo" data-spec="weight">218 g (7.69 oz)</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=build">Build</a></td>\n<td class="nfo" data-spec="build">Glass front (Corning Gorilla Armor 2), glass back (Gorilla Glass Victus 2), titanium frame (grade 5)</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=sim">SIM</a></td>\n<td class="nfo" data-spec="sim">· Nano-SIM + Nano-SIM + <a href="glossary.php3?term=esim">eSIM</a> + eSIM (max 2 at a time) - INT<br/>· Nano-SIM + eSIM + eSIM (max 2 at a time) - USA<br/>· Nano-SIM + Nano-SIM - CN</td>\n</tr>\n<tr><td class="ttl">\xa0</td><td class="nfo" data-spec="bodyother">IP68 dust tight and water resistant (immersible up to 1.5m for 30 min)<br>\r\nStylus</br></td></tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="5" scope="row">Display</th>\n<td class="ttl"><a href="glossary.php3?term=display-type">Type</a></td>\n<td class="nfo" data-spec="displaytype">Dynamic LTPO AMOLED 2X, 120Hz, 480Hz PWM, HDR10+, 2600 nits (peak)</td>\n</tr>\n<tr>\n<td class="ttl"><a href="#" onclick="helpW(\'h_dsize.htm\');">Size</a></td>\n<td class="nfo" data-spec="displaysize">6.9 inches, 116.9 cm<sup>2</sup> (~92.5% screen-to-body ratio)</td>\n</tr>\n<tr>\n<td  ...
#  {'name': 'SamsungGalaxy A17',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_a17_5g-14041.php',
#   'specs_list_html': '<div id="specs-list">\n<style type="text/css"> .tr-toggle {  display:none; }  </style>\n<table cellspacing="0">\n<tr class="tr-hover">\n<th rowspan="15" scope="row">Network</th>\n<td class="ttl"><a href="network-bands.php3">Technology</a></td>\n<td class="nfo"><a class="link-network-detail collapse" data-spec="nettech" href="#">GSM / HSPA / LTE / 5G</a></td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">2G bands</a></td>\n<td class="nfo" data-spec="net2g">GSM 850 / 900 / 1800 / 1900 </td>\n</tr><tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">3G bands</a></td>\n<td class="nfo" data-spec="net3g">HSDPA 850 / 900 / 1700(AWS) / 1900 / 2100 </td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">4G bands</a></td>\n<td class="nfo" data-spec="net4g">1, 2, 3, 4, 5, 7, 8, 12, 17, 20, 28, 38, 40, 41, 66</td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">5G bands</a></td>\n<td class="nfo" data-spec="net5g">1, 3, 5, 7, 8, 20, 28, 38, 40, 41, 66, 77, 78 SA/NSA/Sub6 - International</td>\n</tr>\n<tr class="tr-toggle" data-spec-optional="">\n<td class="ttl">\xa0</td>\n<td class="nfo">1, 3, 5, 7, 8, 26, 28, 40, 41, 66, 77, 78 SA/NSA/Sub6 - India</td>\n</tr>\n<tr class="tr-toggle" data-spec-optional="">\n<td class="ttl">\xa0</td>\n<td class="nfo"> SA/NSA/Sub6/mmWave - USA unlocked</td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="glossary.php3?term=3g">Speed</a></td>\n<td class="nfo" data-spec="speed">HSPA, LTE, 5G</td>\n</tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="2" scope="row">Launch</th>\n<td class="ttl"><a href="glossary.php3?term=phone-life-cycle">Announced</a></td>\n<td class="nfo" data-spec="year">2025, August 06</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=phone-life-cycle">Status</a></td>\n<td class="nfo" data-spec="status">Available. Released 2025, August 14</td>\n</tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="6" scope="row">Body</th>\n<td class="ttl"><a href="#" onclick="helpW(\'h_dimens.htm\');">Dimensions</a></td>\n<td class="nfo" data-spec="dimensions">164.4 x 77.9 x 7.5 mm (6.47 x 3.07 x 0.30 in)</td>\n</tr><tr>\n<td class="ttl"><a href="#" onclick="helpW(\'h_weight.htm\');">Weight</a></td>\n<td class="nfo" data-spec="weight">192 g (6.77 oz)</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=build">Build</a></td>\n<td class="nfo" data-spec="build">Glass front (Gorilla Glass Victus), plastic frame, glass fiber back</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=sim">SIM</a></td>\n<td class="nfo" data-spec="sim">· Nano-SIM<br/>· Nano-SIM + <a href="glossary.php3?term=esim">eSIM</a><br/>· Nano-SIM + Nano-SIM</td>\n</tr>\n<tr><td class="ttl">\xa0</td><td class="nfo" data-spec="bodyother">IP54 dust protected and water resistant (water splashes)</td></tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="5" scope="row">Display</th>\n<td class="ttl"><a href="glossary.php3?term=display-type">Type</a></td>\n<td class="nfo" data-spec="displaytype">Super AMOLED, 90Hz, 800 nits (HBM)</td>\n</tr>\n<tr>\n<td class="ttl"><a href="#" onclick="helpW(\'h_dsize.htm\');">Size</a></td>\n<td class="nfo" data-spec="displaysize">6.7 inches, 110.2 cm<sup>2</sup> (~86.0% screen-to-body ratio)</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=resolution">Resolution</a></td>\n<td class="nfo" data-spec="displayresolution">1080 x 2340 pixels, 19.5:9 ratio (~385 ppi density)</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=screen-protection">Protection</a></td>\n<td class="nfo" data-spec="displayprotection">Corning Gorilla Glass Victus, Mohs level 5</td>\n</tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="4" scope="row">Platform</th>\n<td class="ttl"><a href="glossary.php3?term=os">OS</a></td>\n<td class="nfo" data-spec="os">Android 15, up to 6 major Android upgrades, One UI 7</td>\n</tr>\n<tr><td class ...
#  {'name': 'SamsungGalaxy S25',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s25-13610.php',
#   'specs_list_html': '<div id="specs-list">\n<style type="text/css"> .tr-toggle {  display:none; }  </style>\n<table cellspacing="0">\n<tr class="tr-hover">\n<th rowspan="15" scope="row">Network</th>\n<td class="ttl"><a href="network-bands.php3">Technology</a></td>\n<td class="nfo"><a class="link-network-detail collapse" data-spec="nettech" href="#">GSM / CDMA / HSPA / EVDO / LTE / 5G</a></td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">2G bands</a></td>\n<td class="nfo" data-spec="net2g">GSM 850 / 900 / 1800 / 1900 </td>\n</tr><tr class="tr-toggle" data-spec-optional="">\n<td class="ttl">\xa0</td>\n<td class="nfo">CDMA 800 / 1900 &amp; TD-SCDMA</td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">3G bands</a></td>\n<td class="nfo" data-spec="net3g">HSDPA 850 / 900 / 1700(AWS) / 1900 / 2100 </td>\n</tr>\n<tr class="tr-toggle" data-spec-optional="">\n<td class="ttl">\xa0</td>\n<td class="nfo">CDMA2000 1xEV-DO </td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">4G bands</a></td>\n<td class="nfo" data-spec="net4g">1, 2, 3, 4, 5, 7, 8, 12, 13, 17, 18, 19, 20, 25, 26, 28, 32, 38, 39, 40, 41, 66 - International</td>\n</tr>\n<tr class="tr-toggle" data-spec-optional="">\n<td class="ttl">\xa0</td>\n<td class="nfo">1, 2, 3, 4, 5, 7, 8, 12, 13, 14, 18, 19, 20, 25, 26, 28, 29, 30, 38, 39, 40, 41, 48, 66, 71 - USA unlocked</td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">5G bands</a></td>\n<td class="nfo" data-spec="net5g">1, 2, 3, 5, 7, 8, 12, 20, 25, 26, 28, 38, 40, 41, 66, 75, 77, 78 SA/NSA/Sub6 - International</td>\n</tr>\n<tr class="tr-toggle" data-spec-optional="">\n<td class="ttl">\xa0</td>\n<td class="nfo">1, 2, 5, 7, 25, 28, 41, 66, 71, 77, 78, 257, 258, 260, 261 SA/NSA/Sub6/mmWave - USA unlocked</td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="glossary.php3?term=3g">Speed</a></td>\n<td class="nfo" data-spec="speed">HSPA, LTE (up to 7CA), 5G</td>\n</tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="2" scope="row">Launch</th>\n<td class="ttl"><a href="glossary.php3?term=phone-life-cycle">Announced</a></td>\n<td class="nfo" data-spec="year">2025, January 22</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=phone-life-cycle">Status</a></td>\n<td class="nfo" data-spec="status">Available. Released 2025, February 03</td>\n</tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="6" scope="row">Body</th>\n<td class="ttl"><a href="#" onclick="helpW(\'h_dimens.htm\');">Dimensions</a></td>\n<td class="nfo" data-spec="dimensions">146.9 x 70.5 x 7.2 mm (5.78 x 2.78 x 0.28 in)</td>\n</tr><tr>\n<td class="ttl"><a href="#" onclick="helpW(\'h_weight.htm\');">Weight</a></td>\n<td class="nfo" data-spec="weight">162 g (5.71 oz)</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=build">Build</a></td>\n<td class="nfo" data-spec="build">Glass front (Gorilla Glass Victus 2), glass back (Gorilla Glass Victus 2), aluminum frame</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=sim">SIM</a></td>\n<td class="nfo" data-spec="sim">· Nano-SIM + Nano-SIM + <a href="glossary.php3?term=esim">eSIM</a> + eSIM (max 2 at a time) - INT<br/>· Nano-SIM + eSIM + eSIM (max 2 at a time) - USA<br/>· Nano-SIM + Nano-SIM - CN</td>\n</tr>\n<tr><td class="ttl">\xa0</td><td class="nfo" data-spec="bodyother">IP68 dust tight and water resistant (immersible up to 1.5m for 30 min)<br>\r\nArmor aluminum 2 frame</br></td></tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="5" scope="row">Display</th>\n<td class="ttl"><a href="glossary.php3?term=display-type">Type</a></td>\n<td class="nfo" data-spec="displaytype">Dynamic LTPO AMOLED 2X, 120Hz, 480Hz PWM, HDR10+, 2600 nits (peak)</td>\n</tr>\n<tr>\n<td class="ttl"><a href="#" onclick="helpW(\'h_dsize.htm\');">Size</a></td>\n<td class="nfo" data-spec="displaysize">6.2 inches, 94.4 cm<sup>2</sup> (~91.1% screen-to-body ratio)</td>\n</tr>\n<tr>\n ...
#  {'name': 'SamsungGalaxy A36',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_a36-13497.php',
#   'specs_list_html': '<div id="specs-list">\n<style type="text/css"> .tr-toggle {  display:none; }  </style>\n<table cellspacing="0">\n<tr class="tr-hover">\n<th rowspan="15" scope="row">Network</th>\n<td class="ttl"><a href="network-bands.php3">Technology</a></td>\n<td class="nfo"><a class="link-network-detail collapse" data-spec="nettech" href="#">GSM / HSPA / LTE / 5G</a></td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">2G bands</a></td>\n<td class="nfo" data-spec="net2g">GSM 850 / 900 / 1800 / 1900 </td>\n</tr><tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">3G bands</a></td>\n<td class="nfo" data-spec="net3g">HSDPA 850 / 900 / 1700(AWS) / 1900 / 2100 </td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">4G bands</a></td>\n<td class="nfo" data-spec="net4g">1, 2, 3, 4, 5, 7, 8, 12, 17, 20, 25, 26, 28, 32, 38, 40, 41, 66</td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">5G bands</a></td>\n<td class="nfo" data-spec="net5g">1, 3, 5, 7, 8, 20, 28, 38, 40, 41, 66, 77, 78 SA/NSA/Sub6</td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="glossary.php3?term=3g">Speed</a></td>\n<td class="nfo" data-spec="speed">HSPA, LTE, 5G</td>\n</tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="2" scope="row">Launch</th>\n<td class="ttl"><a href="glossary.php3?term=phone-life-cycle">Announced</a></td>\n<td class="nfo" data-spec="year">2025, March 02</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=phone-life-cycle">Status</a></td>\n<td class="nfo" data-spec="status">Available. Released 2025, March 10</td>\n</tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="6" scope="row">Body</th>\n<td class="ttl"><a href="#" onclick="helpW(\'h_dimens.htm\');">Dimensions</a></td>\n<td class="nfo" data-spec="dimensions">162.9 x 78.2 x 7.4 mm (6.41 x 3.08 x 0.29 in)</td>\n</tr><tr>\n<td class="ttl"><a href="#" onclick="helpW(\'h_weight.htm\');">Weight</a></td>\n<td class="nfo" data-spec="weight">195 g (6.88 oz)</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=build">Build</a></td>\n<td class="nfo" data-spec="build">Glass front (Gorilla Glass Victus+), plastic frame, glass back (Gorilla Glass Victus+)</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=sim">SIM</a></td>\n<td class="nfo" data-spec="sim">Nano-SIM + Nano-SIM + <a href="glossary.php3?term=esim">eSIM</a> + eSIM (max 2 at a time)</td>\n</tr>\n<tr><td class="ttl">\xa0</td><td class="nfo" data-spec="bodyother">IP67 dust/water resistant (up to 1m for 30 min)</td></tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="5" scope="row">Display</th>\n<td class="ttl"><a href="glossary.php3?term=display-type">Type</a></td>\n<td class="nfo" data-spec="displaytype">Super AMOLED, 120Hz, 1200 nits (HBM), 1900 nits (peak)</td>\n</tr>\n<tr>\n<td class="ttl"><a href="#" onclick="helpW(\'h_dsize.htm\');">Size</a></td>\n<td class="nfo" data-spec="displaysize">6.7 inches, 110.2 cm<sup>2</sup> (~86.5% screen-to-body ratio)</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=resolution">Resolution</a></td>\n<td class="nfo" data-spec="displayresolution">1080 x 2340 pixels, 19.5:9 ratio (~385 ppi density)</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=screen-protection">Protection</a></td>\n<td class="nfo" data-spec="displayprotection">Corning Gorilla Glass Victus+, Mohs level 5</td>\n</tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="4" scope="row">Platform</th>\n<td class="ttl"><a href="glossary.php3?term=os">OS</a></td>\n<td class="nfo" data-spec="os">Android 15, up to 6 major Android upgrades, One UI 7</td>\n</tr>\n<tr><td class="ttl"><a href="glossary.php3?term=chipset">Chipset</a></td>\n<td class="nfo" data-spec="chipset">Qualcomm SM6475-AB Snapdragon 6 Gen 3 (4 nm)</td>\n</tr>\n<tr><td class="ttl"><a href="glossary.php3?term=cpu">CPU</a></td>\n<td class="nfo" data-spec="cpu">Octa-core (4x2.4 GHz Cortex- ...
#  {'name': 'SamsungGalaxy S25 FE',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s25_fe_5g-14042.php',
#   'specs_list_html': '<div id="specs-list">\n<style type="text/css"> .tr-toggle {  display:none; }  </style>\n<table cellspacing="0">\n<tr class="tr-hover">\n<th rowspan="15" scope="row">Network</th>\n<td class="ttl"><a href="network-bands.php3">Technology</a></td>\n<td class="nfo"><a class="link-network-detail collapse" data-spec="nettech" href="#">GSM / HSPA / LTE / 5G</a></td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">2G bands</a></td>\n<td class="nfo" data-spec="net2g">GSM 850 / 900 / 1800 / 1900 </td>\n</tr><tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">3G bands</a></td>\n<td class="nfo" data-spec="net3g">HSDPA 850 / 900 / 1700(AWS) / 1900 / 2100 </td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">4G bands</a></td>\n<td class="nfo" data-spec="net4g"> LTE</td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">5G bands</a></td>\n<td class="nfo" data-spec="net5g"> SA/NSA/Sub6</td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="glossary.php3?term=3g">Speed</a></td>\n<td class="nfo" data-spec="speed">HSPA, LTE (CA), 5G</td>\n</tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="2" scope="row">Launch</th>\n<td class="ttl"><a href="glossary.php3?term=phone-life-cycle">Announced</a></td>\n<td class="nfo" data-spec="year">2025, September 04</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=phone-life-cycle">Status</a></td>\n<td class="nfo" data-spec="status">Available. Released 2025, September 04</td>\n</tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="6" scope="row">Body</th>\n<td class="ttl"><a href="#" onclick="helpW(\'h_dimens.htm\');">Dimensions</a></td>\n<td class="nfo" data-spec="dimensions">161.3 x 76.6 x 7.4 mm (6.35 x 3.02 x 0.29 in)</td>\n</tr><tr>\n<td class="ttl"><a href="#" onclick="helpW(\'h_weight.htm\');">Weight</a></td>\n<td class="nfo" data-spec="weight">190 g (6.70 oz)</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=build">Build</a></td>\n<td class="nfo" data-spec="build">Glass front (Gorilla Glass Victus+), glass back (Gorilla Glass Victus+), aluminum frame</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=sim">SIM</a></td>\n<td class="nfo" data-spec="sim">· Nano-SIM<br/>· Nano-SIM + Nano-SIM<br/>· Nano-SIM + <a href="glossary.php3?term=esim">eSIM</a><br/>· eSIM + eSIM</td>\n</tr>\n<tr><td class="ttl">\xa0</td><td class="nfo" data-spec="bodyother">IP68 dust tight and water resistant (immersible up to 1.5m for 30 min)<br>\r\nEnhanced armor aluminum frame</br></td></tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="5" scope="row">Display</th>\n<td class="ttl"><a href="glossary.php3?term=display-type">Type</a></td>\n<td class="nfo" data-spec="displaytype">Dynamic LTPO AMOLED 2X, 120Hz, HDR10+, 1900 nits (peak)</td>\n</tr>\n<tr>\n<td class="ttl"><a href="#" onclick="helpW(\'h_dsize.htm\');">Size</a></td>\n<td class="nfo" data-spec="displaysize">6.7 inches, 110.2 cm<sup>2</sup> (~89.2% screen-to-body ratio)</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=resolution">Resolution</a></td>\n<td class="nfo" data-spec="displayresolution">1080 x 2340 pixels, 19.5:9 ratio (~385 ppi density)</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=screen-protection">Protection</a></td>\n<td class="nfo" data-spec="displayprotection">Corning Gorilla Glass Victus+, Mohs level 5</td>\n</tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="4" scope="row">Platform</th>\n<td class="ttl"><a href="glossary.php3?term=os">OS</a></td>\n<td class="nfo" data-spec="os">Android 16, up to 7 major Android upgrades, One UI 8</td>\n</tr>\n<tr><td class="ttl"><a href="glossary.php3?term=chipset">Chipset</a></td>\n<td class="nfo" data-spec="chipset">Exynos 2400 (4 nm)</td>\n</tr>\n<tr><td class="ttl"><a href="glossary.php3?term=cpu">CPU</a></td>\n<td class="nfo" data-spec="cpu">10-core (1x3.2GHz Cortex-X4 &amp; 2x2.9GHz Cortex-A72 ...
#  {'name': 'SamsungGalaxy A07 4G',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_a07-14066.php',
#   'specs_list_html': '<div id="specs-list">\n<style type="text/css"> .tr-toggle {  display:none; }  </style>\n<table cellspacing="0">\n<tr class="tr-hover">\n<th rowspan="15" scope="row">Network</th>\n<td class="ttl"><a href="network-bands.php3">Technology</a></td>\n<td class="nfo"><a class="link-network-detail collapse" data-spec="nettech" href="#">GSM / HSPA / LTE</a></td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">2G bands</a></td>\n<td class="nfo" data-spec="net2g">GSM 850 / 900 / 1800 / 1900 </td>\n</tr><tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">3G bands</a></td>\n<td class="nfo" data-spec="net3g">HSDPA 850 / 900 / 2100 </td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">4G bands</a></td>\n<td class="nfo" data-spec="net4g">1, 3, 5, 7, 8, 20, 28, 38, 40, 41</td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="glossary.php3?term=3g">Speed</a></td>\n<td class="nfo" data-spec="speed">HSPA, LTE</td>\n</tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="2" scope="row">Launch</th>\n<td class="ttl"><a href="glossary.php3?term=phone-life-cycle">Announced</a></td>\n<td class="nfo" data-spec="year">2025, August 25</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=phone-life-cycle">Status</a></td>\n<td class="nfo" data-spec="status">Available. Released 2025, August 25</td>\n</tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="6" scope="row">Body</th>\n<td class="ttl"><a href="#" onclick="helpW(\'h_dimens.htm\');">Dimensions</a></td>\n<td class="nfo" data-spec="dimensions">167.4 x 77.4 x 7.6 mm (6.59 x 3.05 x 0.30 in)</td>\n</tr><tr>\n<td class="ttl"><a href="#" onclick="helpW(\'h_weight.htm\');">Weight</a></td>\n<td class="nfo" data-spec="weight">184 g (6.49 oz)</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=build">Build</a></td>\n<td class="nfo" data-spec="build">Glass front, plastic back, plastic frame</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=sim">SIM</a></td>\n<td class="nfo" data-spec="sim">Nano-SIM + Nano-SIM</td>\n</tr>\n<tr><td class="ttl">\xa0</td><td class="nfo" data-spec="bodyother">IP54 dust protected and water resistant (water splashes)</td></tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="5" scope="row">Display</th>\n<td class="ttl"><a href="glossary.php3?term=display-type">Type</a></td>\n<td class="nfo" data-spec="displaytype">PLS LCD, 90Hz</td>\n</tr>\n<tr>\n<td class="ttl"><a href="#" onclick="helpW(\'h_dsize.htm\');">Size</a></td>\n<td class="nfo" data-spec="displaysize">6.7 inches, 108.4 cm<sup>2</sup> (~83.6% screen-to-body ratio)</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=resolution">Resolution</a></td>\n<td class="nfo" data-spec="displayresolution">720 x 1600 pixels, 20:9 ratio (~262 ppi density)</td>\n</tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="4" scope="row">Platform</th>\n<td class="ttl"><a href="glossary.php3?term=os">OS</a></td>\n<td class="nfo" data-spec="os">Android 15, up to 6 major Android upgrades, One UI 7</td>\n</tr>\n<tr><td class="ttl"><a href="glossary.php3?term=chipset">Chipset</a></td>\n<td class="nfo" data-spec="chipset">Mediatek Helio G99 (6 nm)</td>\n</tr>\n<tr><td class="ttl"><a href="glossary.php3?term=cpu">CPU</a></td>\n<td class="nfo" data-spec="cpu">Octa-core (2x2.2 GHz Cortex-A76 &amp; 6x2.0 GHz Cortex-A55)</td>\n</tr>\n<tr><td class="ttl"><a href="glossary.php3?term=gpu">GPU</a></td>\n<td class="nfo" data-spec="gpu">Mali-G57 MC2</td>\n</tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="5" scope="row">Memory</th>\n<td class="ttl"><a href="glossary.php3?term=memory-card-slot">Card slot</a></td>\n<td class="nfo" data-spec="memoryslot">microSDXC (dedicated slot)</td></tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=dynamic-memory">Internal</a></td>\n<td class="nfo" data-spec="internalmemory">64GB 4GB RAM, 128GB 4GB RAM, 128GB 6GB RAM, 256GB 8GB RAM</td>\n</tr>\n<t ...
#  {'name': 'SamsungGalaxy S24 Ultra',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s24_ultra-12771.php',
#   'specs_list_html': '<div id="specs-list">\n<style type="text/css"> .tr-toggle {  display:none; }  </style>\n<table cellspacing="0">\n<tr class="tr-hover">\n<th rowspan="15" scope="row">Network</th>\n<td class="ttl"><a href="network-bands.php3">Technology</a></td>\n<td class="nfo"><a class="link-network-detail collapse" data-spec="nettech" href="#">GSM / CDMA / HSPA / EVDO / LTE / 5G</a></td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">2G bands</a></td>\n<td class="nfo" data-spec="net2g">GSM 850 / 900 / 1800 / 1900 </td>\n</tr><tr class="tr-toggle" data-spec-optional="">\n<td class="ttl">\xa0</td>\n<td class="nfo">CDMA 800 / 1900 &amp; TD-SCDMA</td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">3G bands</a></td>\n<td class="nfo" data-spec="net3g">HSDPA 850 / 900 / 1700(AWS) / 1900 / 2100 </td>\n</tr>\n<tr class="tr-toggle" data-spec-optional="">\n<td class="ttl">\xa0</td>\n<td class="nfo">CDMA2000 1xEV-DO </td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">4G bands</a></td>\n<td class="nfo" data-spec="net4g">1, 2, 3, 4, 5, 7, 8, 12, 13, 17, 18, 19, 20, 25, 26, 28, 32, 38, 39, 40, 41, 66 - International</td>\n</tr>\n<tr class="tr-toggle" data-spec-optional="">\n<td class="ttl">\xa0</td>\n<td class="nfo">1, 2, 3, 4, 5, 7, 8, 12, 13, 14, 18, 19, 20, 25, 26, 28, 29, 30, 38, 39, 40, 41, 48, 66, 71 - USA</td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">5G bands</a></td>\n<td class="nfo" data-spec="net5g">1, 2, 3, 5, 7, 8, 12, 20, 25, 26, 28, 38, 40, 41, 66, 75, 77, 78 SA/NSA/Sub6 - International</td>\n</tr>\n<tr class="tr-toggle" data-spec-optional="">\n<td class="ttl">\xa0</td>\n<td class="nfo">1, 7, 25, 28, 41, 66, 71, 78, 257, 258, 260, 261 SA/NSA/Sub6/mmWave - USA</td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="glossary.php3?term=3g">Speed</a></td>\n<td class="nfo" data-spec="speed">HSPA, LTE (up to 7CA), 5G</td>\n</tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="2" scope="row">Launch</th>\n<td class="ttl"><a href="glossary.php3?term=phone-life-cycle">Announced</a></td>\n<td class="nfo" data-spec="year">2024, January 17</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=phone-life-cycle">Status</a></td>\n<td class="nfo" data-spec="status">Available. Released 2024, January 24</td>\n</tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="6" scope="row">Body</th>\n<td class="ttl"><a href="#" onclick="helpW(\'h_dimens.htm\');">Dimensions</a></td>\n<td class="nfo" data-spec="dimensions">162.3 x 79 x 8.6 mm (6.39 x 3.11 x 0.34 in)</td>\n</tr><tr>\n<td class="ttl"><a href="#" onclick="helpW(\'h_weight.htm\');">Weight</a></td>\n<td class="nfo" data-spec="weight">232 g or 233 g (8.18 oz)</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=build">Build</a></td>\n<td class="nfo" data-spec="build">Glass front (Corning Gorilla Armor), glass back (Corning Gorilla Armor), titanium frame (grade 2)</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=sim">SIM</a></td>\n<td class="nfo" data-spec="sim">· Nano-SIM + Nano-SIM + <a href="glossary.php3?term=esim">eSIM</a> + eSIM (max 2 at a time) - INT<br/>· Nano-SIM + eSIM + eSIM (max 2 at a time) - USA<br/>· Nano-SIM + Nano-SIM - CN</td>\n</tr>\n<tr><td class="ttl">\xa0</td><td class="nfo" data-spec="bodyother">IP68 dust tight and water resistant (immersible up to 1.5m for 30 min)<br>\r\nStylus (Bluetooth integration, accelerometer, gyro)</br></td></tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="5" scope="row">Display</th>\n<td class="ttl"><a href="glossary.php3?term=display-type">Type</a></td>\n<td class="nfo" data-spec="displaytype">Dynamic LTPO AMOLED 2X, 120Hz, 480Hz PWM, HDR10+, 2600 nits (peak)</td>\n</tr>\n<tr>\n<td class="ttl"><a href="#" onclick="helpW(\'h_dsize.htm\');">Size</a></td>\n<td class="nfo" data-spec="displaysize">6.8 inches, 113.5 cm<sup>2</sup> (~88.5% screen-to-body ratio)</td ...
#  {'name': 'SamsungGalaxy S24',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s24-12773.php',
#   'specs_list_html': '<div id="specs-list">\n<style type="text/css"> .tr-toggle {  display:none; }  </style>\n<table cellspacing="0">\n<tr class="tr-hover">\n<th rowspan="15" scope="row">Network</th>\n<td class="ttl"><a href="network-bands.php3">Technology</a></td>\n<td class="nfo"><a class="link-network-detail collapse" data-spec="nettech" href="#">GSM / CDMA / HSPA / EVDO / LTE / 5G</a></td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">2G bands</a></td>\n<td class="nfo" data-spec="net2g">GSM 850 / 900 / 1800 / 1900 </td>\n</tr><tr class="tr-toggle" data-spec-optional="">\n<td class="ttl">\xa0</td>\n<td class="nfo">CDMA 800 / 1900 &amp; TD-SCDMA</td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">3G bands</a></td>\n<td class="nfo" data-spec="net3g">HSDPA 850 / 900 / 1700(AWS) / 1900 / 2100 </td>\n</tr>\n<tr class="tr-toggle" data-spec-optional="">\n<td class="ttl">\xa0</td>\n<td class="nfo">CDMA2000 1xEV-DO </td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">4G bands</a></td>\n<td class="nfo" data-spec="net4g">1, 2, 3, 4, 5, 7, 8, 12, 13, 17, 18, 19, 20, 25, 26, 28, 32, 38, 39, 40, 41, 66 - International</td>\n</tr>\n<tr class="tr-toggle" data-spec-optional="">\n<td class="ttl">\xa0</td>\n<td class="nfo">1, 2, 3, 4, 5, 7, 8, 12, 13, 14, 18, 19, 20, 25, 26, 28, 29, 30, 38, 39, 40, 41, 48, 66, 71 - USA</td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">5G bands</a></td>\n<td class="nfo" data-spec="net5g">1, 2, 3, 5, 7, 8, 12, 20, 25, 26, 28, 38, 40, 41, 66, 75, 77, 78 SA/NSA/Sub6 - International</td>\n</tr>\n<tr class="tr-toggle" data-spec-optional="">\n<td class="ttl">\xa0</td>\n<td class="nfo">1, 7, 25, 28, 41, 66, 71, 78, 257, 258, 260, 261 SA/NSA/Sub6/mmWave - USA</td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="glossary.php3?term=3g">Speed</a></td>\n<td class="nfo" data-spec="speed">HSPA, LTE (up to 7CA), 5G</td>\n</tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="2" scope="row">Launch</th>\n<td class="ttl"><a href="glossary.php3?term=phone-life-cycle">Announced</a></td>\n<td class="nfo" data-spec="year">2024, January 17</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=phone-life-cycle">Status</a></td>\n<td class="nfo" data-spec="status">Available. Released 2024, January 24</td>\n</tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="6" scope="row">Body</th>\n<td class="ttl"><a href="#" onclick="helpW(\'h_dimens.htm\');">Dimensions</a></td>\n<td class="nfo" data-spec="dimensions">147 x 70.6 x 7.6 mm (5.79 x 2.78 x 0.30 in)</td>\n</tr><tr>\n<td class="ttl"><a href="#" onclick="helpW(\'h_weight.htm\');">Weight</a></td>\n<td class="nfo" data-spec="weight">167 g or 168 g (5.89 oz)</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=build">Build</a></td>\n<td class="nfo" data-spec="build">Glass front (Gorilla Glass Victus 2), glass back (Gorilla Glass Victus 2), aluminum frame</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=sim">SIM</a></td>\n<td class="nfo" data-spec="sim">· Nano-SIM + Nano-SIM + <a href="glossary.php3?term=esim">eSIM</a> + eSIM (max 2 at a time) - INT<br/>· Nano-SIM + eSIM + eSIM (max 2 at a time) - USA<br/>· Nano-SIM + Nano-SIM - CN</td>\n</tr>\n<tr><td class="ttl">\xa0</td><td class="nfo" data-spec="bodyother">IP68 dust tight and water resistant (immersible up to 1.5m for 30 min)<br>\r\nArmor aluminum 2 frame</br></td></tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="5" scope="row">Display</th>\n<td class="ttl"><a href="glossary.php3?term=display-type">Type</a></td>\n<td class="nfo" data-spec="displaytype">Dynamic LTPO AMOLED 2X, 120Hz, 480Hz PWM, HDR10+, 2600 nits (peak)</td>\n</tr>\n<tr>\n<td class="ttl"><a href="#" onclick="helpW(\'h_dsize.htm\');">Size</a></td>\n<td class="nfo" data-spec="displaysize">6.2 inches, 94.4 cm<sup>2</sup> (~90.9% screen-to-body ratio)</td>\n</tr>\n<tr>\n<td class="ttl"><a hre ...
#  {'name': 'SamsungGalaxy S24 FE',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s24_fe-13262.php',
#   'specs_list_html': '<div id="specs-list">\n<style type="text/css"> .tr-toggle {  display:none; }  </style>\n<table cellspacing="0">\n<tr class="tr-hover">\n<th rowspan="15" scope="row">Network</th>\n<td class="ttl"><a href="network-bands.php3">Technology</a></td>\n<td class="nfo"><a class="link-network-detail collapse" data-spec="nettech" href="#">GSM / HSPA / LTE / 5G</a></td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">2G bands</a></td>\n<td class="nfo" data-spec="net2g">GSM 850 / 900 / 1800 / 1900 </td>\n</tr><tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">3G bands</a></td>\n<td class="nfo" data-spec="net3g">HSDPA 850 / 900 / 1700(AWS) / 1900 / 2100 </td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">4G bands</a></td>\n<td class="nfo" data-spec="net4g">1, 2, 3, 4, 5, 7, 8, 12, 17, 18, 19, 20, 25, 26, 28, 32, 38, 40, 41, 66 - International</td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">5G bands</a></td>\n<td class="nfo" data-spec="net5g">1, 2, 3, 5, 7, 8, 12, 20, 25, 26, 28, 38, 40, 41, 66, 75, 77, 78 SA/NSA/Sub6 - International</td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="glossary.php3?term=3g">Speed</a></td>\n<td class="nfo" data-spec="speed">HSPA, LTE (CA), 5G</td>\n</tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="2" scope="row">Launch</th>\n<td class="ttl"><a href="glossary.php3?term=phone-life-cycle">Announced</a></td>\n<td class="nfo" data-spec="year">2024, September 26</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=phone-life-cycle">Status</a></td>\n<td class="nfo" data-spec="status">Available. Released 2024, October 03</td>\n</tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="6" scope="row">Body</th>\n<td class="ttl"><a href="#" onclick="helpW(\'h_dimens.htm\');">Dimensions</a></td>\n<td class="nfo" data-spec="dimensions">162 x 77.3 x 8 mm (6.38 x 3.04 x 0.31 in)</td>\n</tr><tr>\n<td class="ttl"><a href="#" onclick="helpW(\'h_weight.htm\');">Weight</a></td>\n<td class="nfo" data-spec="weight">213 g (7.51 oz)</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=build">Build</a></td>\n<td class="nfo" data-spec="build">Glass front (Gorilla Glass Victus+), glass back (Gorilla Glass Victus+), aluminum frame</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=sim">SIM</a></td>\n<td class="nfo" data-spec="sim">· Nano-SIM<br/>· Nano-SIM + Nano-SIM<br/>· Nano-SIM + <a href="glossary.php3?term=esim">eSIM</a><br/>· eSIM + eSIM</td>\n</tr>\n<tr><td class="ttl">\xa0</td><td class="nfo" data-spec="bodyother">IP68 dust tight and water resistant (immersible up to 1.5m for 30 min)</td></tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="5" scope="row">Display</th>\n<td class="ttl"><a href="glossary.php3?term=display-type">Type</a></td>\n<td class="nfo" data-spec="displaytype">Dynamic AMOLED 2X, 120Hz, HDR10+, 1900 nits (peak)</td>\n</tr>\n<tr>\n<td class="ttl"><a href="#" onclick="helpW(\'h_dsize.htm\');">Size</a></td>\n<td class="nfo" data-spec="displaysize">6.7 inches, 110.2 cm<sup>2</sup> (~88.0% screen-to-body ratio)</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=resolution">Resolution</a></td>\n<td class="nfo" data-spec="displayresolution">1080 x 2340 pixels, 19.5:9 ratio (~385 ppi density)</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=screen-protection">Protection</a></td>\n<td class="nfo" data-spec="displayprotection">Corning Gorilla Glass Victus+, Mohs level 5</td>\n</tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="4" scope="row">Platform</th>\n<td class="ttl"><a href="glossary.php3?term=os">OS</a></td>\n<td class="nfo" data-spec="os">Android 14, up to 7 major Android upgrades, One UI 8.0</td>\n</tr>\n<tr><td class="ttl"><a href="glossary.php3?term=chipset">Chipset</a></td>\n<td class="nfo" data-spec="chipset">Exynos 2400e (4 nm)</td>\n</tr>\n<tr><td class="ttl"><a href="glossary.p ...
#  {'name': 'SamsungGalaxy A55',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_a55-12824.php',
#   'specs_list_html': '<div id="specs-list">\n<style type="text/css"> .tr-toggle {  display:none; }  </style>\n<table cellspacing="0">\n<tr class="tr-hover">\n<th rowspan="15" scope="row">Network</th>\n<td class="ttl"><a href="network-bands.php3">Technology</a></td>\n<td class="nfo"><a class="link-network-detail collapse" data-spec="nettech" href="#">GSM / HSPA / LTE / 5G</a></td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">2G bands</a></td>\n<td class="nfo" data-spec="net2g">GSM 850 / 900 / 1800 / 1900 </td>\n</tr><tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">3G bands</a></td>\n<td class="nfo" data-spec="net3g">HSDPA 850 / 900 / 1700(AWS) / 1900 / 2100 </td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">4G bands</a></td>\n<td class="nfo" data-spec="net4g">1, 2, 3, 4, 5, 7, 8, 12, 17, 20, 25, 26, 28, 32, 38, 40, 41, 66</td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">5G bands</a></td>\n<td class="nfo" data-spec="net5g">1, 3, 5, 7, 8, 20, 28, 38, 40, 41, 66, 77, 78 SA/NSA/Sub6</td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="glossary.php3?term=3g">Speed</a></td>\n<td class="nfo" data-spec="speed">HSPA, LTE, 5G</td>\n</tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="2" scope="row">Launch</th>\n<td class="ttl"><a href="glossary.php3?term=phone-life-cycle">Announced</a></td>\n<td class="nfo" data-spec="year">2024, March 11</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=phone-life-cycle">Status</a></td>\n<td class="nfo" data-spec="status">Available. Released 2024, March 15</td>\n</tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="6" scope="row">Body</th>\n<td class="ttl"><a href="#" onclick="helpW(\'h_dimens.htm\');">Dimensions</a></td>\n<td class="nfo" data-spec="dimensions">161.1 x 77.4 x 8.2 mm (6.34 x 3.05 x 0.32 in)</td>\n</tr><tr>\n<td class="ttl"><a href="#" onclick="helpW(\'h_weight.htm\');">Weight</a></td>\n<td class="nfo" data-spec="weight">213 g (7.51 oz)</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=build">Build</a></td>\n<td class="nfo" data-spec="build">Glass front (Gorilla Glass Victus+), glass back (Gorilla Glass), aluminum frame</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=sim">SIM</a></td>\n<td class="nfo" data-spec="sim">· Nano-SIM<br/>· Nano-SIM + <a href="glossary.php3?term=esim">eSIM</a><br/>· Nano-SIM + Nano-SIM<br/>· Nano-SIM + Nano-SIM + eSIM (max 2 at a time)</td>\n</tr>\n<tr><td class="ttl">\xa0</td><td class="nfo" data-spec="bodyother">IP67 dust/water resistant (up to 1m for 30 min)</td></tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="5" scope="row">Display</th>\n<td class="ttl"><a href="glossary.php3?term=display-type">Type</a></td>\n<td class="nfo" data-spec="displaytype">Super AMOLED, 120Hz, HDR10+, 1000 nits (HBM)</td>\n</tr>\n<tr>\n<td class="ttl"><a href="#" onclick="helpW(\'h_dsize.htm\');">Size</a></td>\n<td class="nfo" data-spec="displaysize">6.6 inches, 106.9 cm<sup>2</sup> (~85.8% screen-to-body ratio)</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=resolution">Resolution</a></td>\n<td class="nfo" data-spec="displayresolution">1080 x 2340 pixels, 19.5:9 ratio (~390 ppi density)</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=screen-protection">Protection</a></td>\n<td class="nfo" data-spec="displayprotection">Corning Gorilla Glass Victus+</td>\n</tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="4" scope="row">Platform</th>\n<td class="ttl"><a href="glossary.php3?term=os">OS</a></td>\n<td class="nfo" data-spec="os">Android 14, up to 4 major Android upgrades, One UI 6.1</td>\n</tr>\n<tr><td class="ttl"><a href="glossary.php3?term=chipset">Chipset</a></td>\n<td class="nfo" data-spec="chipset">Exynos 1480 (4 nm)</td>\n</tr>\n<tr><td class="ttl"><a href="glossary.php3?term=cpu">CPU</a></td>\n<td class="nfo" data-spec="cpu">Octa-core (4x2.75 GHz Cor ...
#  {'name': 'SamsungGalaxy A26',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_a26-13679.php',
# ...
#  {'name': 'SamsungGalaxy S25+',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s25+-13609.php',
#   'specs_list_html': '<div id="specs-list">\n<style type="text/css"> .tr-toggle {  display:none; }  </style>\n<table cellspacing="0">\n<tr class="tr-hover">\n<th rowspan="15" scope="row">Network</th>\n<td class="ttl"><a href="network-bands.php3">Technology</a></td>\n<td class="nfo"><a class="link-network-detail collapse" data-spec="nettech" href="#">GSM / CDMA / HSPA / EVDO / LTE / 5G</a></td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">2G bands</a></td>\n<td class="nfo" data-spec="net2g">GSM 850 / 900 / 1800 / 1900 </td>\n</tr><tr class="tr-toggle" data-spec-optional="">\n<td class="ttl">\xa0</td>\n<td class="nfo">CDMA 800 / 1900 &amp; TD-SCDMA</td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">3G bands</a></td>\n<td class="nfo" data-spec="net3g">HSDPA 850 / 900 / 1700(AWS) / 1900 / 2100 </td>\n</tr>\n<tr class="tr-toggle" data-spec-optional="">\n<td class="ttl">\xa0</td>\n<td class="nfo">CDMA2000 1xEV-DO </td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">4G bands</a></td>\n<td class="nfo" data-spec="net4g">1, 2, 3, 4, 5, 7, 8, 12, 13, 17, 18, 19, 20, 25, 26, 28, 32, 38, 39, 40, 41, 66 - International</td>\n</tr>\n<tr class="tr-toggle" data-spec-optional="">\n<td class="ttl">\xa0</td>\n<td class="nfo">1, 2, 3, 4, 5, 7, 8, 12, 13, 14, 18, 19, 20, 25, 26, 28, 29, 30, 38, 39, 40, 41, 48, 66, 71 - USA unlocked</td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">5G bands</a></td>\n<td class="nfo" data-spec="net5g">1, 2, 3, 5, 7, 8, 12, 20, 25, 26, 28, 38, 40, 41, 66, 75, 77, 78 SA/NSA/Sub6 - International</td>\n</tr>\n<tr class="tr-toggle" data-spec-optional="">\n<td class="ttl">\xa0</td>\n<td class="nfo">1, 2, 5, 7, 25, 28, 41, 66, 71, 77, 78, 257, 258, 260, 261 SA/NSA/Sub6/mmWave - USA unlocked</td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="glossary.php3?term=3g">Speed</a></td>\n<td class="nfo" data-spec="speed">HSPA, LTE (up to 7CA), 5G</td>\n</tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="2" scope="row">Launch</th>\n<td class="ttl"><a href="glossary.php3?term=phone-life-cycle">Announced</a></td>\n<td class="nfo" data-spec="year">2025, January 22</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=phone-life-cycle">Status</a></td>\n<td class="nfo" data-spec="status">Available. Released 2025, February 03</td>\n</tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="6" scope="row">Body</th>\n<td class="ttl"><a href="#" onclick="helpW(\'h_dimens.htm\');">Dimensions</a></td>\n<td class="nfo" data-spec="dimensions">158.4 x 75.8 x 7.3 mm (6.24 x 2.98 x 0.29 in)</td>\n</tr><tr>\n<td class="ttl"><a href="#" onclick="helpW(\'h_weight.htm\');">Weight</a></td>\n<td class="nfo" data-spec="weight">190 g (6.70 oz)</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=build">Build</a></td>\n<td class="nfo" data-spec="build">Glass front (Gorilla Glass Victus 2), glass back (Gorilla Glass Victus 2), aluminum frame</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=sim">SIM</a></td>\n<td class="nfo" data-spec="sim">· Nano-SIM + Nano-SIM + <a href="glossary.php3?term=esim">eSIM</a> + eSIM (max 2 at a time) - INT<br/>· Nano-SIM + eSIM + eSIM (max 2 at a time) - USA<br/>· Nano-SIM + Nano-SIM - CN</td>\n</tr>\n<tr><td class="ttl">\xa0</td><td class="nfo" data-spec="bodyother">IP68 dust tight and water resistant (immersible up to 1.5m for 30 min)<br>\r\nArmor aluminum 2 frame</br></td></tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="5" scope="row">Display</th>\n<td class="ttl"><a href="glossary.php3?term=display-type">Type</a></td>\n<td class="nfo" data-spec="displaytype">Dynamic LTPO AMOLED 2X, 120Hz, 480Hz PWM, HDR10+, 2600 nits (peak)</td>\n</tr>\n<tr>\n<td class="ttl"><a href="#" onclick="helpW(\'h_dsize.htm\');">Size</a></td>\n<td class="nfo" data-spec="displaysize">6.7 inches, 110.2 cm<sup>2</sup> (~91.8% screen-to-body ratio)</td>\n</tr>\n<tr>\ ...
#  {'name': 'SamsungGalaxy S21 FE 5G',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s21_fe_5g-10954.php',
#   'specs_list_html': '<div id="specs-list">\n<style type="text/css"> .tr-toggle {  display:none; }  </style>\n<table cellspacing="0">\n<tr class="tr-hover">\n<th rowspan="15" scope="row">Network</th>\n<td class="ttl"><a href="network-bands.php3">Technology</a></td>\n<td class="nfo"><a class="link-network-detail collapse" data-spec="nettech" href="#">GSM / CDMA / HSPA / EVDO / LTE / 5G</a></td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">2G bands</a></td>\n<td class="nfo" data-spec="net2g">GSM 850 / 900 / 1800 / 1900 </td>\n</tr><tr class="tr-toggle" data-spec-optional="">\n<td class="ttl">\xa0</td>\n<td class="nfo">CDMA 800 / 1900 &amp; TD-SCDMA</td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">3G bands</a></td>\n<td class="nfo" data-spec="net3g">HSDPA 850 / 900 / 1700(AWS) / 1900 / 2100 </td>\n</tr>\n<tr class="tr-toggle" data-spec-optional="">\n<td class="ttl">\xa0</td>\n<td class="nfo">CDMA2000 1xEV-DO </td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">4G bands</a></td>\n<td class="nfo" data-spec="net4g">1, 2, 3, 4, 5, 7, 8, 12, 17, 20, 26, 28, 32, 38, 40, 41, 66 - International</td>\n</tr>\n<tr class="tr-toggle" data-spec-optional="">\n<td class="ttl">\xa0</td>\n<td class="nfo">1, 2, 3, 4, 5, 7, 12, 13, 29, 25, 26, 28, 38, 39, 40, 41, 46, 48, 66, 71 - USA</td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">5G bands</a></td>\n<td class="nfo" data-spec="net5g">1, 3, 5, 8, 20, 28, 38, 40, 41, 66, 78 SA/NSA/Sub6 - International</td>\n</tr>\n<tr class="tr-toggle" data-spec-optional="">\n<td class="ttl">\xa0</td>\n<td class="nfo">41, 66, 71, 260, 261 SA/NSA/Sub6/mmWave - USA</td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="glossary.php3?term=3g">Speed</a></td>\n<td class="nfo" data-spec="speed">HSPA 42.2/5.76 Mbps, LTE (5CA) Cat19 1600/200 Mbps, 5G</td>\n</tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="2" scope="row">Launch</th>\n<td class="ttl"><a href="glossary.php3?term=phone-life-cycle">Announced</a></td>\n<td class="nfo" data-spec="year">2022, January 04</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=phone-life-cycle">Status</a></td>\n<td class="nfo" data-spec="status">Available. Released 2022, January 07</td>\n</tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="6" scope="row">Body</th>\n<td class="ttl"><a href="#" onclick="helpW(\'h_dimens.htm\');">Dimensions</a></td>\n<td class="nfo" data-spec="dimensions">155.7 x 74.5 x 7.9 mm (6.13 x 2.93 x 0.31 in)</td>\n</tr><tr>\n<td class="ttl"><a href="#" onclick="helpW(\'h_weight.htm\');">Weight</a></td>\n<td class="nfo" data-spec="weight">177 g (6.24 oz)</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=build">Build</a></td>\n<td class="nfo" data-spec="build">Glass front (Gorilla Glass Victus), plastic back, aluminum frame</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=sim">SIM</a></td>\n<td class="nfo" data-spec="sim">· Nano-SIM<br/>· Nano-SIM + Nano-SIM</td>\n</tr>\n<tr><td class="ttl">\xa0</td><td class="nfo" data-spec="bodyother">IP68 dust tight and water resistant (immersible up to 1.5m for 30 min)</td></tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="5" scope="row">Display</th>\n<td class="ttl"><a href="glossary.php3?term=display-type">Type</a></td>\n<td class="nfo" data-spec="displaytype">Dynamic AMOLED 2X, 120Hz, HDR10+</td>\n</tr>\n<tr>\n<td class="ttl"><a href="#" onclick="helpW(\'h_dsize.htm\');">Size</a></td>\n<td class="nfo" data-spec="displaysize">6.4 inches, 100.5 cm<sup>2</sup> (~86.7% screen-to-body ratio)</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=resolution">Resolution</a></td>\n<td class="nfo" data-spec="displayresolution">1080 x 2340 pixels, 19.5:9 ratio (~403 ppi density)</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=screen-protection">Protection</a></td>\n<td class="nfo" data-spec="displayprotection">Corning ...
#  {'name': 'SamsungGalaxy A05',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_a05-12583.php',
#   'specs_list_html': '<div id="specs-list">\n<style type="text/css"> .tr-toggle {  display:none; }  </style>\n<table cellspacing="0">\n<tr class="tr-hover">\n<th rowspan="15" scope="row">Network</th>\n<td class="ttl"><a href="network-bands.php3">Technology</a></td>\n<td class="nfo"><a class="link-network-detail collapse" data-spec="nettech" href="#">GSM / HSPA / LTE</a></td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">2G bands</a></td>\n<td class="nfo" data-spec="net2g">GSM 850 / 900 / 1800 / 1900 </td>\n</tr><tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">3G bands</a></td>\n<td class="nfo" data-spec="net3g">HSDPA 850 / 900 / 2100 </td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="network-bands.php3">4G bands</a></td>\n<td class="nfo" data-spec="net4g">1, 3, 5, 7, 8, 20, 28, 38, 40, 41</td>\n</tr>\n<tr class="tr-toggle">\n<td class="ttl"><a href="glossary.php3?term=3g">Speed</a></td>\n<td class="nfo" data-spec="speed">HSPA, LTE</td>\n</tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="2" scope="row">Launch</th>\n<td class="ttl"><a href="glossary.php3?term=phone-life-cycle">Announced</a></td>\n<td class="nfo" data-spec="year">2023, September 25</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=phone-life-cycle">Status</a></td>\n<td class="nfo" data-spec="status">Available. Released 2023, October 15</td>\n</tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="6" scope="row">Body</th>\n<td class="ttl"><a href="#" onclick="helpW(\'h_dimens.htm\');">Dimensions</a></td>\n<td class="nfo" data-spec="dimensions">168.8 x 78.2 x 8.8 mm (6.65 x 3.08 x 0.35 in)</td>\n</tr><tr>\n<td class="ttl"><a href="#" onclick="helpW(\'h_weight.htm\');">Weight</a></td>\n<td class="nfo" data-spec="weight">195 g (6.88 oz)</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=build">Build</a></td>\n<td class="nfo" data-spec="build">Glass front, plastic back, plastic frame</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=sim">SIM</a></td>\n<td class="nfo" data-spec="sim">· Nano-SIM<br/>· Nano-SIM + Nano-SIM</td>\n</tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="5" scope="row">Display</th>\n<td class="ttl"><a href="glossary.php3?term=display-type">Type</a></td>\n<td class="nfo" data-spec="displaytype">PLS LCD</td>\n</tr>\n<tr>\n<td class="ttl"><a href="#" onclick="helpW(\'h_dsize.htm\');">Size</a></td>\n<td class="nfo" data-spec="displaysize">6.7 inches, 108.4 cm<sup>2</sup> (~82.1% screen-to-body ratio)</td>\n</tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=resolution">Resolution</a></td>\n<td class="nfo" data-spec="displayresolution">720 x 1600 pixels, 20:9 ratio (~262 ppi density)</td>\n</tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="4" scope="row">Platform</th>\n<td class="ttl"><a href="glossary.php3?term=os">OS</a></td>\n<td class="nfo" data-spec="os">Android 13, up to 2 major Android upgrades, One UI 7</td>\n</tr>\n<tr><td class="ttl"><a href="glossary.php3?term=chipset">Chipset</a></td>\n<td class="nfo" data-spec="chipset">Mediatek Helio G85 (12 nm)</td>\n</tr>\n<tr><td class="ttl"><a href="glossary.php3?term=cpu">CPU</a></td>\n<td class="nfo" data-spec="cpu">Octa-core (2x2.0 GHz Cortex-A75 &amp; 6x1.8 GHz Cortex-A55)</td>\n</tr>\n<tr><td class="ttl"><a href="glossary.php3?term=gpu">GPU</a></td>\n<td class="nfo" data-spec="gpu">Mali-G52 MC2</td>\n</tr>\n</table>\n<table cellspacing="0">\n<tr>\n<th rowspan="5" scope="row">Memory</th>\n<td class="ttl"><a href="glossary.php3?term=memory-card-slot">Card slot</a></td>\n<td class="nfo" data-spec="memoryslot">microSDXC</td></tr>\n<tr>\n<td class="ttl"><a href="glossary.php3?term=dynamic-memory">Internal</a></td>\n<td class="nfo" data-spec="internalmemory">32GB 3GB RAM, 64GB 4GB RAM, 128GB 4GB RAM, 128GB 6GB RAM</td>\n</tr>\n<tr><td class="ttl">\xa0</td><td class="nfo" data-spec="memoryother">eMMC 5.1</td></tr>\n\n\n</table>\n<table cellspacing="0">\n<tr>\n<th c ...

# %%
import re

STATUS_PATTERN = re.compile(r'data-spec="status">([^<]+)')
DISPLAY_PATTERN = re.compile(r'data-spec="displaysize">([^<]+)')
BATTERY_PATTERN = re.compile(r'data-spec="batdescription1">([^<]+)')
CAMERA_PATTERN = re.compile(r'data-spec="cam1modules">([^<]+)')
MEMORY_PATTERN = re.compile(r'data-spec="internalmemory">([^<]+)')
PRICE_PATTERN = re.compile(r'data-spec="price"><a[^>]*>([^<]+)')

for item in final_data:
    html_str = item['specs_list_html']
    
    match = STATUS_PATTERN.search(html_str)
    item['released'] = match.group(1).strip() if match else 'N/A'
    
    match = DISPLAY_PATTERN.search(html_str)
    item['display'] = match.group(1).strip() if match else 'N/A'
    
    match = BATTERY_PATTERN.search(html_str)
    item['battery'] = match.group(1).strip() if match else 'N/A'
    
    match = CAMERA_PATTERN.search(html_str)
    if match:
        raw_camera = match.group(1).replace('\\r\\n', ' ').replace('<br>', ' ').strip()
        item['camera'] = re.sub('<[^>]+>', '', raw_camera)
    else:
        item['camera'] = 'N/A'
    
    match = MEMORY_PATTERN.search(html_str)
    item['memory'] = match.group(1).strip() if match else 'N/A'
    
    match = PRICE_PATTERN.search(html_str)
    if match:
        item['price'] = match.group(1).strip().replace('\u2009', ' ')
    else:
        item['price'] = 'N/A'
        
    del item['specs_list_html']

# %%
final_data
# Out:
# [{'name': 'SamsungGalaxy A56',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_a56-13603.php',
#   'released': 'Available. Released 2025, March 10',
#   'display': '6.7 inches, 110.2 cm',
#   'battery': '5000 mAh',
#   'camera': '50 MP, f/1.8, (wide), 1/1.56", 1.0µm, PDAF, OIS',
#   'memory': '128GB 6GB RAM, 128GB 8GB RAM, 256GB 6GB RAM, 256GB 8GB RAM, 256GB 12GB RAM',
#   'price': '$ 305.00 / € 290.00 / £ 252.00 / ₹ 32,724'},
#  {'name': 'SamsungGalaxy S25 Ultra',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s25_ultra-13322.php',
#   'released': 'Available. Released 2025, February 03',
#   'display': '6.9 inches, 116.9 cm',
#   'battery': 'Li-Ion 5000 mAh',
#   'camera': '200 MP, f/1.7, 24mm (wide), 1/1.3", 0.6µm, multi-directional PDAF, OIS',
#   'memory': '256GB 12GB RAM, 512GB 12GB RAM, 1TB 12GB RAM, 1TB 16GB RAM',
#   'price': '$ 689.94 / € 920.00 / £ 770.00 / ₹ 97,500'},
#  {'name': 'SamsungGalaxy A17',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_a17_5g-14041.php',
#   'released': 'Available. Released 2025, August 14',
#   'display': '6.7 inches, 110.2 cm',
#   'battery': '5000 mAh',
#   'camera': '50 MP, f/1.8, (wide), 1/2.76", 0.64µm, AF, OIS',
#   'memory': '128GB 4GB RAM, 128GB 6GB RAM, 128GB 8GB RAM, 256GB 4GB RAM, 256GB 8GB RAM',
#   'price': '$ 205.00 / € 168.00 / £ 182.00 / ₹ 18,999'},
#  {'name': 'SamsungGalaxy S25',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s25-13610.php',
#   'released': 'Available. Released 2025, February 03',
#   'display': '6.2 inches, 94.4 cm',
#   'battery': 'Li-Ion 4000 mAh',
#   'camera': '50 MP, f/1.8, 24mm (wide), 1/1.56", 1.0µm, dual pixel PDAF, OIS',
#   'memory': '128GB 12GB RAM, 256GB 12GB RAM, 512GB 12GB RAM',
#   'price': '$ 457.00 / € 519.00 / £ 479.99 / ₹ 61,350'},
#  {'name': 'SamsungGalaxy A36',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_a36-13497.php',
#   'released': 'Available. Released 2025, March 10',
#   'display': '6.7 inches, 110.2 cm',
#   'battery': '5000 mAh',
#   'camera': '50 MP, f/1.8, (wide), 1/1.96", PDAF, OIS',
#   'memory': '128GB 6GB RAM, 128GB 8GB RAM, 256GB 6GB RAM, 256GB 8GB RAM, 256GB 12GB RAM',
#   'price': '$ 248.00 / € 242.99 / £ 215.00 / ₹ 28,499'},
#  {'name': 'SamsungGalaxy S25 FE',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s25_fe_5g-14042.php',
#   'released': 'Available. Released 2025, September 04',
#   'display': '6.7 inches, 110.2 cm',
#   'battery': '4900 mAh',
#   'camera': '50 MP, f/1.8, 24mm (wide), 1/1.57", 1.0µm, dual pixel PDAF, OIS',
#   'memory': '128GB 8GB RAM, 256GB 8GB RAM, 512GB 8GB RAM',
#   'price': '$ 623.99 / € 578.00 / £ 599.00 / ₹ 65,999'},
#  {'name': 'SamsungGalaxy A07 4G',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_a07-14066.php',
#   'released': 'Available. Released 2025, August 25',
#   'display': '6.7 inches, 108.4 cm',
#   'battery': '5000 mAh',
#   'camera': '50 MP, f/1.8, (wide), 1/2.76", 0.64µm, PDAF',
#   'memory': '64GB 4GB RAM, 128GB 4GB RAM, 128GB 6GB RAM, 256GB 8GB RAM',
#   'price': '$ 143.64'},
#  {'name': 'SamsungGalaxy S24 Ultra',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s24_ultra-12771.php',
#   'released': 'Available. Released 2024, January 24',
#   'display': '6.8 inches, 113.5 cm',
#   'battery': 'Li-Ion 5000 mAh',
#   'camera': '200 MP, f/1.7, 24mm (wide), 1/1.3", 0.6µm, multi-directional PDAF, OIS',
#   'memory': '256GB 12GB RAM, 512GB 12GB RAM, 1TB 12GB RAM',
#   'price': '$ 574.90 / € 705.34 / £ 579.95 / ₹ 79,999'},
#  {'name': 'SamsungGalaxy S24',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s24-12773.php',
#   'released': 'Available. Released 2024, January 24',
#   'display': '6.2 inches, 94.4 cm',
#   'battery': 'Li-Ion 4000 mAh',
#   'camera': '50 MP, f/1.8, 24mm (wide), 1/1.56", 1.0µm, dual pixel PDAF, OIS',
#   'memory': '128GB 8GB RAM, 256GB 8GB RAM, 256GB 12GB RAM, 512GB 8GB RAM',
#   'price': '$ 289.95 / € 430.00 / £ 368.00 / ₹ 41,560'},
#  {'name': 'SamsungGalaxy S24 FE',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s24_fe-13262.php',
#   'released': 'Available. Released 2024, October 03',
#   'display': '6.7 inches, 110.2 cm',
#   'battery': '4700 mAh',
#   'camera': '50 MP, f/1.8, 24mm (wide), 1/1.57", 1.0µm, dual pixel PDAF, OIS',
#   'memory': '128GB 8GB RAM, 256GB 8GB RAM, 512GB 8GB RAM',
#   'price': '$ 250.00 / € 391.90 / £ 364.00 / ₹ 30,999'},
#  {'name': 'SamsungGalaxy A55',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_a55-12824.php',
#   'released': 'Available. Released 2024, March 15',
#   'display': '6.6 inches, 106.9 cm',
#   'battery': 'Li-Ion 5000 mAh',
#   'camera': '50 MP, f/1.8, (wide), 1/1.56", 1.0µm, PDAF, OIS',
#   'memory': '128GB 6GB RAM, 128GB 8GB RAM, 256GB 6GB RAM, 256GB 8GB RAM, 256GB 12GB RAM',
#   'price': '$ 382.50 / € 310.00 / £ 240.00 / ₹ 20,399'},
#  {'name': 'SamsungGalaxy A26',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_a26-13679.php',
#   'released': 'Available. Released 2025, March 19',
#   'display': '6.7 inches, 110.2 cm',
#   'battery': '5000 mAh',
#   'camera': '50 MP, f/1.8, 27mm (wide), 1/2.76", 0.64µm, PDAF, OIS',
#   'memory': '128GB 4GB RAM, 128GB 6GB RAM, 128GB 8GB RAM, 256GB 6GB RAM, 256GB 8GB RAM',
#   'price': '$ 180.49 / € 198.69 / £ 167.51 / ₹ 23,999'},
#  {'name': 'SamsungGalaxy A16 5G',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_a16_5g-13346.php',
#   'released': 'Available. Released 2024, October 25',
#   'display': '6.7 inches, 110.2 cm',
#   'battery': '5000 mAh',
#   'camera': '50 MP, f/1.8, (wide), 1/2.76", 0.64µm, AF',
#   'memory': '128GB 4GB RAM, 128GB 6GB RAM, 128GB 8GB RAM, 256GB 6GB RAM, 256GB 8GB RAM',
#   'price': '$ 129.99 / € 159.00 / £ 129.50 / ₹ 18,999'},
#  {'name': 'SamsungGalaxy S22 Ultra 5G',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s22_ultra_5g-11251.php',
#   'released': 'Available. Released 2022, February 25',
#   'display': '6.8 inches, 114.7 cm',
#   'battery': 'Li-Ion 5000 mAh',
#   'camera': '108 MP, f/1.8, 23mm (wide), 1/1.33", 0.8µm, PDAF, OIS',
#   'memory': '128GB 8GB RAM, 256GB 12GB RAM, 512GB 12GB RAM, 1TB 12GB RAM',
#   'price': '$ 273.27 / € 424.50 / £ 303.40 / ₹ 65,999'},
#  {'name': 'SamsungGalaxy A16',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_a16-13383.php',
#   'released': 'Available. Released 2024, November 20',
#   'display': '6.7 inches, 110.2 cm',
#   'battery': '5000 mAh',
#   'camera': '50 MP, f/1.8, (wide), 1/2.76", 0.64µm, AF',
#   'memory': '128GB 4GB RAM, 128GB 6GB RAM, 128GB 8GB RAM, 256GB 4GB RAM, 256GB 6GB RAM, 256GB 8GB RAM',
#   'price': '$ 123.75 / € 122.00 / £ 99.49'},
#  {'name': 'SamsungGalaxy A06',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_a06-13265.php',
#   'released': 'Available. Released 2024, August 22',
#   'display': '6.7 inches, 108.4 cm',
#   'battery': 'Li-Po 5000 mAh',
#   'camera': '50 MP, f/1.8, (wide), 1/2.76", 0.64µm, PDAF',
#   'memory': '64GB 4GB RAM, 128GB 4GB RAM, 128GB 6GB RAM',
#   'price': '$ 102.00 / € 85.12 / £ 67.00 / ₹ 7,599'},
#  {'name': 'SamsungGalaxy S23 Ultra',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s23_ultra-12024.php',
#   'released': 'Available. Released 2023, February 17',
#   'display': '6.8 inches, 114.7 cm',
#   'battery': 'Li-Ion 5000 mAh',
#   'camera': '200 MP, f/1.7, 24mm (wide), 1/1.3", 0.6µm, multi-directional PDAF, OIS',
#   'memory': '256GB 8GB RAM, 256GB 12GB RAM, 512GB 12GB RAM, 1TB 12GB RAM',
#   'price': '$ 470.00 / € 442.57 / £ 439.00 / ₹ 78,399'},
#  {'name': 'SamsungGalaxy A35',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_a35-12705.php',
#   'released': 'Available. Released 2024, March 15',
#   'display': '6.6 inches, 106.9 cm',
#   'battery': 'Li-Ion 5000 mAh',
#   'camera': '50 MP, f/1.8, (wide), 1/1.96", PDAF, OIS',
#   'memory': '128GB 4GB RAM, 128GB 6GB RAM, 128GB 8GB RAM, 256GB 6GB RAM, 256GB 8GB RAM, 256GB 12GB RAM',
#   'price': '$ 119.00 / € 199.99 / £ 214.99 / ₹ 17,999'},
#  {'name': 'SamsungGalaxy S23',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s23-12082.php',
#   'released': 'Available. Released 2023, February 17',
#   'display': '6.1 inches, 90.1 cm',
#   'battery': 'Li-Ion 3900 mAh',
#   'camera': '50 MP, f/1.8, 24mm (wide), 1/1.56", 1.0µm, dual pixel PDAF, OIS',
#   'memory': '128GB 8GB RAM, 256GB 8GB RAM, 512GB 8GB RAM',
#   'price': '$ 229.85 / € 330.00 / £ 253.25 / ₹ 46,990'},
#  {'name': 'SamsungGalaxy S22 5G',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s22_5g-11253.php',
#   'released': 'Available. Released 2022, February 25',
#   'display': '6.1 inches, 90.1 cm',
#   'battery': 'Li-Ion 3700 mAh',
#   'camera': '50 MP, f/1.8, 23mm (wide), 1/1.56", 1.0µm, dual pixel PDAF, OIS',
#   'memory': '128GB 8GB RAM, 256GB 8GB RAM',
#   'price': '$ 163.04 / € 234.66 / £ 184.00'},
#  {'name': 'SamsungGalaxy S25 Edge',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s25_edge-13506.php',
#   'released': 'Available. Released 2025, May 29',
#   'display': '6.7 inches, 110.2 cm',
#   'battery': 'Li-Ion 3900 mAh',
#   'camera': '200 MP, f/1.7, 24mm (wide), 1/1.3", 0.6µm, multi-directional PDAF, OIS',
#   'memory': '256GB 12GB RAM, 512GB 12GB RAM',
#   'price': '$ 539.94 / € 665.00 / £ 699.99 / ₹ 101,999'},
#  {'name': 'SamsungGalaxy Z Fold7',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_z_fold7-13826.php',
#   'released': 'Available. Released 2025, July 25',
#   'display': '8.0 inches, 204.2 cm',
#   'battery': 'Li-Po 4400 mAh',
#   'camera': '200 MP, f/1.7, 24mm (wide), 1/1.3", 0.6µm, multi-directional PDAF, OIS',
#   'memory': '256GB 12GB RAM, 512GB 12GB RAM, 1TB 12GB RAM, 1TB 16GB RAM',
#   'price': '$ 1,599.99 / € 1,275.00 / £ 1,575.66 / ₹ 174,999'},
#  {'name': 'SamsungGalaxy A15',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_a15-12637.php',
#   'released': 'Available. Released 2023, December 16',
#   'display': '6.5 inches, 103.7 cm',
#   'battery': '5000 mAh',
#   'camera': '50 MP, f/1.8, 26mm (wide), 1/2.8", 0.64µm, PDAF',
#   'memory': '128GB 4GB RAM, 128GB 6GB RAM, 128GB 8GB RAM, 256GB 6GB RAM, 256GB 8GB RAM',
#   'price': '$ 169.99 / € 174.99 / £ 101.02'},
#  {'name': 'SamsungGalaxy S21 5G',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s21_5g-10626.php',
#   'released': 'Available. Released 2021, January 29',
#   'display': '6.2 inches, 94.1 cm',
#   'battery': 'Li-Ion 4000 mAh',
#   'camera': '12 MP, f/1.8, 26mm (wide), 1/1.76", 1.8µm, dual pixel PDAF, OIS',
#   'memory': '128GB 6GB RAM, 128GB 8GB RAM, 256GB 8GB RAM',
#   'price': '$ 149.77 / € 198.99 / £ 153.50'},
#  {'name': 'SamsungGalaxy S21 Ultra 5G',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s21_ultra_5g-10596.php',
#   'released': 'Available. Released 2021, January 29',
#   'display': '6.8 inches, 112.1 cm',
#   'battery': 'Li-Ion 5000 mAh',
#   'camera': '108 MP, f/1.8, 24mm (wide), 1/1.33", 0.8µm, PDAF, OIS',
#   'memory': '128GB 8GB RAM, 128GB 12GB RAM, 256GB 12GB RAM, 256GB 16GB RAM, 512GB 12GB RAM, 512GB 16GB RAM',
#   'price': '$ 249.00 / € 267.99 / £ 205.29'},
#  {'name': 'SamsungGalaxy A54',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_a54-12070.php',
#   'released': 'Available. Released 2023, March 24',
#   'display': '6.4 inches, 100.5 cm',
#   'battery': '5000 mAh',
#   'camera': '50 MP, f/1.8, 23mm (wide), 1/1.56", 1.0µm, PDAF, OIS',
#   'memory': '128GB 4GB RAM, 128GB 6GB RAM, 128GB 8GB RAM, 256GB 6GB RAM, 256GB 8GB RAM',
#   'price': '$ 119.11 / € 213.00 / £ 174.99 / ₹ 28,999'},
#  {'name': 'SamsungGalaxy M17',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_m17_5g-14221.php',
#   'released': 'Available. Released Exp. release 2025, October 13',
#   'display': '6.7 inches, 110.2 cm',
#   'battery': '5000 mAh',
#   'camera': '50 MP, f/1.8, (wide), 1/2.76", 0.64µm, AF, OIS',
#   'memory': '128GB 4GB RAM, 128GB 6GB RAM, 128GB 8GB RAM',
#   'price': 'N/A'},
#  {'name': 'SamsungGalaxy S25+',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s25+-13609.php',
#   'released': 'Available. Released 2025, February 03',
#   'display': '6.7 inches, 110.2 cm',
#   'battery': 'Li-Ion 4900 mAh',
#   'camera': '50 MP, f/1.8, 24mm (wide), 1/1.56", 1.0µm, dual pixel PDAF, OIS',
#   'memory': '256GB 12GB RAM, 512GB 12GB RAM',
#   'price': '$ 899.99 / € 815.00 / £ 803.00'},
#  {'name': 'SamsungGalaxy S21 FE 5G',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s21_fe_5g-10954.php',
#   'released': 'Available. Released 2022, January 07',
#   'display': '6.4 inches, 100.5 cm',
#   'battery': 'Li-Ion 4500 mAh',
#   'camera': '12 MP, f/1.8, 26mm (wide), 1/1.76", 1.8µm, dual pixel PDAF, OIS',
#   'memory': '128GB 6GB RAM, 128GB 8GB RAM, 256GB 6GB RAM, 256GB 8GB RAM',
#   'price': '$ 136.77 / € 256.00 / £ 189.00'},
#  {'name': 'SamsungGalaxy A05',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_a05-12583.php',
#   'released': 'Available. Released 2023, October 15',
#   'display': '6.7 inches, 108.4 cm',
#   'battery': 'Li-Po 5000 mAh',
#   'camera': '50 MP, f/1.8, (wide),  1/2.8", 0.64µm, AF',
#   'memory': '32GB 3GB RAM, 64GB 4GB RAM, 128GB 4GB RAM, 128GB 6GB RAM',
#   'price': '$ 84.99 / € 96.07 / £ 69.70 / ₹ 8,949'}]

# %%
unique_ram = set()
unique_storage = set()

MEMORY_PATTERN = re.compile(r'(\d+GB)(?:\s+RAM)?')

for item in final_data:
    memory_string = item['memory']
    
    configurations = [s.strip() for s in memory_string.split(',')]
    
    for config in configurations:
        matches = MEMORY_PATTERN.findall(config)
        
        if len(matches) == 2:
            unique_storage.add(matches[0].strip())
            unique_ram.add(matches[1].strip())
        elif len(matches) == 1 and 'RAM' in config:
             unique_ram.add(matches[0].strip())
        elif len(matches) == 1:
            unique_storage.add(matches[0].strip())

    item['ram'] = ', '.join(sorted(list(unique_ram), key=lambda x: int(re.findall(r'\d+', x)[0])))
    item['storage'] = ', '.join(sorted(list(unique_storage), key=lambda x: int(re.findall(r'\d+', x)[0])))
    
    del item['memory']
    
    unique_ram.clear()
    unique_storage.clear()

# %%
final_data
# Out:
# [{'name': 'SamsungGalaxy A56',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_a56-13603.php',
#   'released': 'Available. Released 2025, March 10',
#   'display': '6.7 inches, 110.2 cm',
#   'battery': '5000 mAh',
#   'camera': '50 MP, f/1.8, (wide), 1/1.56", 1.0µm, PDAF, OIS',
#   'price': '$ 305.00 / € 290.00 / £ 252.00 / ₹ 32,724',
#   'ram': '6GB, 8GB, 12GB',
#   'storage': '128GB, 256GB'},
#  {'name': 'SamsungGalaxy S25 Ultra',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s25_ultra-13322.php',
#   'released': 'Available. Released 2025, February 03',
#   'display': '6.9 inches, 116.9 cm',
#   'battery': 'Li-Ion 5000 mAh',
#   'camera': '200 MP, f/1.7, 24mm (wide), 1/1.3", 0.6µm, multi-directional PDAF, OIS',
#   'price': '$ 689.94 / € 920.00 / £ 770.00 / ₹ 97,500',
#   'ram': '12GB, 16GB',
#   'storage': '256GB, 512GB'},
#  {'name': 'SamsungGalaxy A17',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_a17_5g-14041.php',
#   'released': 'Available. Released 2025, August 14',
#   'display': '6.7 inches, 110.2 cm',
#   'battery': '5000 mAh',
#   'camera': '50 MP, f/1.8, (wide), 1/2.76", 0.64µm, AF, OIS',
#   'price': '$ 205.00 / € 168.00 / £ 182.00 / ₹ 18,999',
#   'ram': '4GB, 6GB, 8GB',
#   'storage': '128GB, 256GB'},
#  {'name': 'SamsungGalaxy S25',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s25-13610.php',
#   'released': 'Available. Released 2025, February 03',
#   'display': '6.2 inches, 94.4 cm',
#   'battery': 'Li-Ion 4000 mAh',
#   'camera': '50 MP, f/1.8, 24mm (wide), 1/1.56", 1.0µm, dual pixel PDAF, OIS',
#   'price': '$ 457.00 / € 519.00 / £ 479.99 / ₹ 61,350',
#   'ram': '12GB',
#   'storage': '128GB, 256GB, 512GB'},
#  {'name': 'SamsungGalaxy A36',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_a36-13497.php',
#   'released': 'Available. Released 2025, March 10',
#   'display': '6.7 inches, 110.2 cm',
#   'battery': '5000 mAh',
#   'camera': '50 MP, f/1.8, (wide), 1/1.96", PDAF, OIS',
#   'price': '$ 248.00 / € 242.99 / £ 215.00 / ₹ 28,499',
#   'ram': '6GB, 8GB, 12GB',
#   'storage': '128GB, 256GB'},
#  {'name': 'SamsungGalaxy S25 FE',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s25_fe_5g-14042.php',
#   'released': 'Available. Released 2025, September 04',
#   'display': '6.7 inches, 110.2 cm',
#   'battery': '4900 mAh',
#   'camera': '50 MP, f/1.8, 24mm (wide), 1/1.57", 1.0µm, dual pixel PDAF, OIS',
#   'price': '$ 623.99 / € 578.00 / £ 599.00 / ₹ 65,999',
#   'ram': '8GB',
#   'storage': '128GB, 256GB, 512GB'},
#  {'name': 'SamsungGalaxy A07 4G',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_a07-14066.php',
#   'released': 'Available. Released 2025, August 25',
#   'display': '6.7 inches, 108.4 cm',
#   'battery': '5000 mAh',
#   'camera': '50 MP, f/1.8, (wide), 1/2.76", 0.64µm, PDAF',
#   'price': '$ 143.64',
#   'ram': '4GB, 6GB, 8GB',
#   'storage': '64GB, 128GB, 256GB'},
#  {'name': 'SamsungGalaxy S24 Ultra',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s24_ultra-12771.php',
#   'released': 'Available. Released 2024, January 24',
#   'display': '6.8 inches, 113.5 cm',
#   'battery': 'Li-Ion 5000 mAh',
#   'camera': '200 MP, f/1.7, 24mm (wide), 1/1.3", 0.6µm, multi-directional PDAF, OIS',
#   'price': '$ 574.90 / € 705.34 / £ 579.95 / ₹ 79,999',
#   'ram': '12GB',
#   'storage': '256GB, 512GB'},
#  {'name': 'SamsungGalaxy S24',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s24-12773.php',
#   'released': 'Available. Released 2024, January 24',
#   'display': '6.2 inches, 94.4 cm',
#   'battery': 'Li-Ion 4000 mAh',
#   'camera': '50 MP, f/1.8, 24mm (wide), 1/1.56", 1.0µm, dual pixel PDAF, OIS',
#   'price': '$ 289.95 / € 430.00 / £ 368.00 / ₹ 41,560',
#   'ram': '8GB, 12GB',
#   'storage': '128GB, 256GB, 512GB'},
#  {'name': 'SamsungGalaxy S24 FE',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s24_fe-13262.php',
#   'released': 'Available. Released 2024, October 03',
#   'display': '6.7 inches, 110.2 cm',
#   'battery': '4700 mAh',
#   'camera': '50 MP, f/1.8, 24mm (wide), 1/1.57", 1.0µm, dual pixel PDAF, OIS',
#   'price': '$ 250.00 / € 391.90 / £ 364.00 / ₹ 30,999',
#   'ram': '8GB',
#   'storage': '128GB, 256GB, 512GB'},
#  {'name': 'SamsungGalaxy A55',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_a55-12824.php',
#   'released': 'Available. Released 2024, March 15',
#   'display': '6.6 inches, 106.9 cm',
#   'battery': 'Li-Ion 5000 mAh',
#   'camera': '50 MP, f/1.8, (wide), 1/1.56", 1.0µm, PDAF, OIS',
#   'price': '$ 382.50 / € 310.00 / £ 240.00 / ₹ 20,399',
#   'ram': '6GB, 8GB, 12GB',
#   'storage': '128GB, 256GB'},
#  {'name': 'SamsungGalaxy A26',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_a26-13679.php',
#   'released': 'Available. Released 2025, March 19',
#   'display': '6.7 inches, 110.2 cm',
#   'battery': '5000 mAh',
#   'camera': '50 MP, f/1.8, 27mm (wide), 1/2.76", 0.64µm, PDAF, OIS',
#   'price': '$ 180.49 / € 198.69 / £ 167.51 / ₹ 23,999',
#   'ram': '4GB, 6GB, 8GB',
#   'storage': '128GB, 256GB'},
#  {'name': 'SamsungGalaxy A16 5G',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_a16_5g-13346.php',
#   'released': 'Available. Released 2024, October 25',
#   'display': '6.7 inches, 110.2 cm',
#   'battery': '5000 mAh',
#   'camera': '50 MP, f/1.8, (wide), 1/2.76", 0.64µm, AF',
#   'price': '$ 129.99 / € 159.00 / £ 129.50 / ₹ 18,999',
#   'ram': '4GB, 6GB, 8GB',
#   'storage': '128GB, 256GB'},
#  {'name': 'SamsungGalaxy S22 Ultra 5G',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s22_ultra_5g-11251.php',
#   'released': 'Available. Released 2022, February 25',
#   'display': '6.8 inches, 114.7 cm',
#   'battery': 'Li-Ion 5000 mAh',
#   'camera': '108 MP, f/1.8, 23mm (wide), 1/1.33", 0.8µm, PDAF, OIS',
#   'price': '$ 273.27 / € 424.50 / £ 303.40 / ₹ 65,999',
#   'ram': '8GB, 12GB',
#   'storage': '128GB, 256GB, 512GB'},
#  {'name': 'SamsungGalaxy A16',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_a16-13383.php',
#   'released': 'Available. Released 2024, November 20',
#   'display': '6.7 inches, 110.2 cm',
#   'battery': '5000 mAh',
#   'camera': '50 MP, f/1.8, (wide), 1/2.76", 0.64µm, AF',
#   'price': '$ 123.75 / € 122.00 / £ 99.49',
#   'ram': '4GB, 6GB, 8GB',
#   'storage': '128GB, 256GB'},
#  {'name': 'SamsungGalaxy A06',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_a06-13265.php',
#   'released': 'Available. Released 2024, August 22',
#   'display': '6.7 inches, 108.4 cm',
#   'battery': 'Li-Po 5000 mAh',
#   'camera': '50 MP, f/1.8, (wide), 1/2.76", 0.64µm, PDAF',
#   'price': '$ 102.00 / € 85.12 / £ 67.00 / ₹ 7,599',
#   'ram': '4GB, 6GB',
#   'storage': '64GB, 128GB'},
#  {'name': 'SamsungGalaxy S23 Ultra',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s23_ultra-12024.php',
#   'released': 'Available. Released 2023, February 17',
#   'display': '6.8 inches, 114.7 cm',
#   'battery': 'Li-Ion 5000 mAh',
#   'camera': '200 MP, f/1.7, 24mm (wide), 1/1.3", 0.6µm, multi-directional PDAF, OIS',
#   'price': '$ 470.00 / € 442.57 / £ 439.00 / ₹ 78,399',
#   'ram': '8GB, 12GB',
#   'storage': '256GB, 512GB'},
#  {'name': 'SamsungGalaxy A35',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_a35-12705.php',
#   'released': 'Available. Released 2024, March 15',
#   'display': '6.6 inches, 106.9 cm',
#   'battery': 'Li-Ion 5000 mAh',
#   'camera': '50 MP, f/1.8, (wide), 1/1.96", PDAF, OIS',
#   'price': '$ 119.00 / € 199.99 / £ 214.99 / ₹ 17,999',
#   'ram': '4GB, 6GB, 8GB, 12GB',
#   'storage': '128GB, 256GB'},
#  {'name': 'SamsungGalaxy S23',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s23-12082.php',
#   'released': 'Available. Released 2023, February 17',
#   'display': '6.1 inches, 90.1 cm',
#   'battery': 'Li-Ion 3900 mAh',
#   'camera': '50 MP, f/1.8, 24mm (wide), 1/1.56", 1.0µm, dual pixel PDAF, OIS',
#   'price': '$ 229.85 / € 330.00 / £ 253.25 / ₹ 46,990',
#   'ram': '8GB',
#   'storage': '128GB, 256GB, 512GB'},
#  {'name': 'SamsungGalaxy S22 5G',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s22_5g-11253.php',
#   'released': 'Available. Released 2022, February 25',
#   'display': '6.1 inches, 90.1 cm',
#   'battery': 'Li-Ion 3700 mAh',
#   'camera': '50 MP, f/1.8, 23mm (wide), 1/1.56", 1.0µm, dual pixel PDAF, OIS',
#   'price': '$ 163.04 / € 234.66 / £ 184.00',
#   'ram': '8GB',
#   'storage': '128GB, 256GB'},
#  {'name': 'SamsungGalaxy S25 Edge',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s25_edge-13506.php',
#   'released': 'Available. Released 2025, May 29',
#   'display': '6.7 inches, 110.2 cm',
#   'battery': 'Li-Ion 3900 mAh',
#   'camera': '200 MP, f/1.7, 24mm (wide), 1/1.3", 0.6µm, multi-directional PDAF, OIS',
#   'price': '$ 539.94 / € 665.00 / £ 699.99 / ₹ 101,999',
#   'ram': '12GB',
#   'storage': '256GB, 512GB'},
#  {'name': 'SamsungGalaxy Z Fold7',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_z_fold7-13826.php',
#   'released': 'Available. Released 2025, July 25',
#   'display': '8.0 inches, 204.2 cm',
#   'battery': 'Li-Po 4400 mAh',
#   'camera': '200 MP, f/1.7, 24mm (wide), 1/1.3", 0.6µm, multi-directional PDAF, OIS',
#   'price': '$ 1,599.99 / € 1,275.00 / £ 1,575.66 / ₹ 174,999',
#   'ram': '12GB, 16GB',
#   'storage': '256GB, 512GB'},
#  {'name': 'SamsungGalaxy A15',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_a15-12637.php',
#   'released': 'Available. Released 2023, December 16',
#   'display': '6.5 inches, 103.7 cm',
#   'battery': '5000 mAh',
#   'camera': '50 MP, f/1.8, 26mm (wide), 1/2.8", 0.64µm, PDAF',
#   'price': '$ 169.99 / € 174.99 / £ 101.02',
#   'ram': '4GB, 6GB, 8GB',
#   'storage': '128GB, 256GB'},
#  {'name': 'SamsungGalaxy S21 5G',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s21_5g-10626.php',
#   'released': 'Available. Released 2021, January 29',
#   'display': '6.2 inches, 94.1 cm',
#   'battery': 'Li-Ion 4000 mAh',
#   'camera': '12 MP, f/1.8, 26mm (wide), 1/1.76", 1.8µm, dual pixel PDAF, OIS',
#   'price': '$ 149.77 / € 198.99 / £ 153.50',
#   'ram': '6GB, 8GB',
#   'storage': '128GB, 256GB'},
#  {'name': 'SamsungGalaxy S21 Ultra 5G',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s21_ultra_5g-10596.php',
#   'released': 'Available. Released 2021, January 29',
#   'display': '6.8 inches, 112.1 cm',
#   'battery': 'Li-Ion 5000 mAh',
#   'camera': '108 MP, f/1.8, 24mm (wide), 1/1.33", 0.8µm, PDAF, OIS',
#   'price': '$ 249.00 / € 267.99 / £ 205.29',
#   'ram': '8GB, 12GB, 16GB',
#   'storage': '128GB, 256GB, 512GB'},
#  {'name': 'SamsungGalaxy A54',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_a54-12070.php',
#   'released': 'Available. Released 2023, March 24',
#   'display': '6.4 inches, 100.5 cm',
#   'battery': '5000 mAh',
#   'camera': '50 MP, f/1.8, 23mm (wide), 1/1.56", 1.0µm, PDAF, OIS',
#   'price': '$ 119.11 / € 213.00 / £ 174.99 / ₹ 28,999',
#   'ram': '4GB, 6GB, 8GB',
#   'storage': '128GB, 256GB'},
#  {'name': 'SamsungGalaxy M17',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_m17_5g-14221.php',
#   'released': 'Available. Released Exp. release 2025, October 13',
#   'display': '6.7 inches, 110.2 cm',
#   'battery': '5000 mAh',
#   'camera': '50 MP, f/1.8, (wide), 1/2.76", 0.64µm, AF, OIS',
#   'price': 'N/A',
#   'ram': '4GB, 6GB, 8GB',
#   'storage': '128GB'},
#  {'name': 'SamsungGalaxy S25+',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s25+-13609.php',
#   'released': 'Available. Released 2025, February 03',
#   'display': '6.7 inches, 110.2 cm',
#   'battery': 'Li-Ion 4900 mAh',
#   'camera': '50 MP, f/1.8, 24mm (wide), 1/1.56", 1.0µm, dual pixel PDAF, OIS',
#   'price': '$ 899.99 / € 815.00 / £ 803.00',
#   'ram': '12GB',
#   'storage': '256GB, 512GB'},
#  {'name': 'SamsungGalaxy S21 FE 5G',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_s21_fe_5g-10954.php',
#   'released': 'Available. Released 2022, January 07',
#   'display': '6.4 inches, 100.5 cm',
#   'battery': 'Li-Ion 4500 mAh',
#   'camera': '12 MP, f/1.8, 26mm (wide), 1/1.76", 1.8µm, dual pixel PDAF, OIS',
#   'price': '$ 136.77 / € 256.00 / £ 189.00',
#   'ram': '6GB, 8GB',
#   'storage': '128GB, 256GB'},
#  {'name': 'SamsungGalaxy A05',
#   'link': 'https://www.gsmarena.com/samsung_galaxy_a05-12583.php',
#   'released': 'Available. Released 2023, October 15',
#   'display': '6.7 inches, 108.4 cm',
#   'battery': 'Li-Po 5000 mAh',
#   'camera': '50 MP, f/1.8, (wide),  1/2.8", 0.64µm, AF',
#   'price': '$ 84.99 / € 96.07 / £ 69.70 / ₹ 8,949',
#   'ram': '3GB, 4GB, 6GB',
#   'storage': '32GB, 64GB, 128GB'}]

# %%
df = pd.DataFrame(final_data)

# %%
df
# Out:
#                           name  \
# 0            SamsungGalaxy A56
# 1      SamsungGalaxy S25 Ultra
# 2            SamsungGalaxy A17
# 3            SamsungGalaxy S25
# 4            SamsungGalaxy A36
# 5         SamsungGalaxy S25 FE
# 6         SamsungGalaxy A07 4G
# 7      SamsungGalaxy S24 Ultra
# 8            SamsungGalaxy S24
# 9         SamsungGalaxy S24 FE
# 10           SamsungGalaxy A55
# 11           SamsungGalaxy A26
# 12        SamsungGalaxy A16 5G
# 13  SamsungGalaxy S22 Ultra 5G
# 14           SamsungGalaxy A16
# 15           SamsungGalaxy A06
# 16     SamsungGalaxy S23 Ultra
# 17           SamsungGalaxy A35
# 18           SamsungGalaxy S23
# 19        SamsungGalaxy S22 5G
# 20      SamsungGalaxy S25 Edge
# 21       SamsungGalaxy Z Fold7
# 22           SamsungGalaxy A15
# 23        SamsungGalaxy S21 5G
# 24  SamsungGalaxy S21 Ultra 5G
# 25           SamsungGalaxy A54
# 26           SamsungGalaxy M17
# 27          SamsungGalaxy S25+
# 28     SamsungGalaxy S21 FE 5G
# 29           SamsungGalaxy A05
#
#                                                  link  \
# 0   https://www.gsmarena.com/samsung_galaxy_a56-13...
# 1   https://www.gsmarena.com/samsung_galaxy_s25_ul...
# 2   https://www.gsmarena.com/samsung_galaxy_a17_5g...
# 3   https://www.gsmarena.com/samsung_galaxy_s25-13...
# 4   https://www.gsmarena.com/samsung_galaxy_a36-13...
# 5   https://www.gsmarena.com/samsung_galaxy_s25_fe...
# 6   https://www.gsmarena.com/samsung_galaxy_a07-14...
# 7   https://www.gsmarena.com/samsung_galaxy_s24_ul...
# 8   https://www.gsmarena.com/samsung_galaxy_s24-12...
# 9   https://www.gsmarena.com/samsung_galaxy_s24_fe...
# 10  https://www.gsmarena.com/samsung_galaxy_a55-12...
# 11  https://www.gsmarena.com/samsung_galaxy_a26-13...
# 12  https://www.gsmarena.com/samsung_galaxy_a16_5g...
# 13  https://www.gsmarena.com/samsung_galaxy_s22_ul...
# 14  https://www.gsmarena.com/samsung_galaxy_a16-13...
# 15  https://www.gsmarena.com/samsung_galaxy_a06-13...
# 16  https://www.gsmarena.com/samsung_galaxy_s23_ul...
# 17  https://www.gsmarena.com/samsung_galaxy_a35-12...
# 18  https://www.gsmarena.com/samsung_galaxy_s23-12...
# 19  https://www.gsmarena.com/samsung_galaxy_s22_5g...
# 20  https://www.gsmarena.com/samsung_galaxy_s25_ed...
# 21  https://www.gsmarena.com/samsung_galaxy_z_fold...
# 22  https://www.gsmarena.com/samsung_galaxy_a15-12...
# 23  https://www.gsmarena.com/samsung_galaxy_s21_5g...
# 24  https://www.gsmarena.com/samsung_galaxy_s21_ul...
# 25  https://www.gsmarena.com/samsung_galaxy_a54-12...
# 26  https://www.gsmarena.com/samsung_galaxy_m17_5g...
# 27  https://www.gsmarena.com/samsung_galaxy_s25+-1...
# 28  https://www.gsmarena.com/samsung_galaxy_s21_fe...
# 29  https://www.gsmarena.com/samsung_galaxy_a05-12...
#
#                                              released               display  \
# 0                  Available. Released 2025, March 10  6.7 inches, 110.2 cm
# 1               Available. Released 2025, February 03  6.9 inches, 116.9 cm
# 2                 Available. Released 2025, August 14  6.7 inches, 110.2 cm
# 3               Available. Released 2025, February 03   6.2 inches, 94.4 cm
# 4                  Available. Released 2025, March 10  6.7 inches, 110.2 cm
# 5              Available. Released 2025, September 04  6.7 inches, 110.2 cm
# 6                 Available. Released 2025, August 25  6.7 inches, 108.4 cm
# 7                Available. Released 2024, January 24  6.8 inches, 113.5 cm
# 8                Available. Released 2024, January 24   6.2 inches, 94.4 cm
# 9                Available. Released 2024, October 03  6.7 inches, 110.2 cm
# 10                 Available. Released 2024, March 15  6.6 inches, 106.9 cm
# 11                 Available. Released 2025, March 19  6.7 inches, 110.2 cm
# 12               Available. Released 2024, October 25  6.7 inches, 110.2 cm
# 13              Available. Released 2022, February 25  6.8 inches, 114.7 cm
# 14              Available. Released 2024, November 20  6.7 inches, 110.2 cm
# 15                Available. Released 2024, August 22  6.7 inches, 108.4 cm
# 16              Available. Released 2023, February 17  6.8 inches, 114.7 cm
# 17                 Available. Released 2024, March 15  6.6 inches, 106.9 cm
# 18              Available. Released 2023, February 17   6.1 inches, 90.1 cm
# 19              Available. Released 2022, February 25   6.1 inches, 90.1 cm
# 20                   Available. Released 2025, May 29  6.7 inches, 110.2 cm
# 21                  Available. Released 2025, July 25  8.0 inches, 204.2 cm
# 22              Available. Released 2023, December 16  6.5 inches, 103.7 cm
# 23               Available. Released 2021, January 29   6.2 inches, 94.1 cm
# 24               Available. Released 2021, January 29  6.8 inches, 112.1 cm
# 25                 Available. Released 2023, March 24  6.4 inches, 100.5 cm
# 26  Available. Released Exp. release 2025, October 13  6.7 inches, 110.2 cm
# 27              Available. Released 2025, February 03  6.7 inches, 110.2 cm
# 28               Available. Released 2022, January 07  6.4 inches, 100.5 cm
# 29               Available. Released 2023, October 15  6.7 inches, 108.4 cm
#
#             battery                                             camera  \
# 0          5000 mAh    50 MP, f/1.8, (wide), 1/1.56", 1.0µm, PDAF, OIS
# 1   Li-Ion 5000 mAh  200 MP, f/1.7, 24mm (wide), 1/1.3", 0.6µm, mul...
# 2          5000 mAh     50 MP, f/1.8, (wide), 1/2.76", 0.64µm, AF, OIS
# 3   Li-Ion 4000 mAh  50 MP, f/1.8, 24mm (wide), 1/1.56", 1.0µm, dua...
# 4          5000 mAh           50 MP, f/1.8, (wide), 1/1.96", PDAF, OIS
# 5          4900 mAh  50 MP, f/1.8, 24mm (wide), 1/1.57", 1.0µm, dua...
# 6          5000 mAh        50 MP, f/1.8, (wide), 1/2.76", 0.64µm, PDAF
# 7   Li-Ion 5000 mAh  200 MP, f/1.7, 24mm (wide), 1/1.3", 0.6µm, mul...
# 8   Li-Ion 4000 mAh  50 MP, f/1.8, 24mm (wide), 1/1.56", 1.0µm, dua...
# 9          4700 mAh  50 MP, f/1.8, 24mm (wide), 1/1.57", 1.0µm, dua...
# 10  Li-Ion 5000 mAh    50 MP, f/1.8, (wide), 1/1.56", 1.0µm, PDAF, OIS
# 11         5000 mAh  50 MP, f/1.8, 27mm (wide), 1/2.76", 0.64µm, PD...
# 12         5000 mAh          50 MP, f/1.8, (wide), 1/2.76", 0.64µm, AF
# 13  Li-Ion 5000 mAh  108 MP, f/1.8, 23mm (wide), 1/1.33", 0.8µm, PD...
# 14         5000 mAh          50 MP, f/1.8, (wide), 1/2.76", 0.64µm, AF
# 15   Li-Po 5000 mAh        50 MP, f/1.8, (wide), 1/2.76", 0.64µm, PDAF
# 16  Li-Ion 5000 mAh  200 MP, f/1.7, 24mm (wide), 1/1.3", 0.6µm, mul...
# 17  Li-Ion 5000 mAh           50 MP, f/1.8, (wide), 1/1.96", PDAF, OIS
# 18  Li-Ion 3900 mAh  50 MP, f/1.8, 24mm (wide), 1/1.56", 1.0µm, dua...
# 19  Li-Ion 3700 mAh  50 MP, f/1.8, 23mm (wide), 1/1.56", 1.0µm, dua...
# 20  Li-Ion 3900 mAh  200 MP, f/1.7, 24mm (wide), 1/1.3", 0.6µm, mul...
# 21   Li-Po 4400 mAh  200 MP, f/1.7, 24mm (wide), 1/1.3", 0.6µm, mul...
# 22         5000 mAh    50 MP, f/1.8, 26mm (wide), 1/2.8", 0.64µm, PDAF
# 23  Li-Ion 4000 mAh  12 MP, f/1.8, 26mm (wide), 1/1.76", 1.8µm, dua...
# 24  Li-Ion 5000 mAh  108 MP, f/1.8, 24mm (wide), 1/1.33", 0.8µm, PD...
# 25         5000 mAh  50 MP, f/1.8, 23mm (wide), 1/1.56", 1.0µm, PDA...
# 26         5000 mAh     50 MP, f/1.8, (wide), 1/2.76", 0.64µm, AF, OIS
# 27  Li-Ion 4900 mAh  50 MP, f/1.8, 24mm (wide), 1/1.56", 1.0µm, dua...
# 28  Li-Ion 4500 mAh  12 MP, f/1.8, 26mm (wide), 1/1.76", 1.8µm, dua...
# 29   Li-Po 5000 mAh          50 MP, f/1.8, (wide),  1/2.8", 0.64µm, AF
#
#                                                price                  ram  \
# 0          $ 305.00 / € 290.00 / £ 252.00 / ₹ 32,724       6GB, 8GB, 12GB
# 1          $ 689.94 / € 920.00 / £ 770.00 / ₹ 97,500           12GB, 16GB
# 2          $ 205.00 / € 168.00 / £ 182.00 / ₹ 18,999        4GB, 6GB, 8GB
# 3          $ 457.00 / € 519.00 / £ 479.99 / ₹ 61,350                 12GB
# 4          $ 248.00 / € 242.99 / £ 215.00 / ₹ 28,499       6GB, 8GB, 12GB
# 5          $ 623.99 / € 578.00 / £ 599.00 / ₹ 65,999                  8GB
# 6                                           $ 143.64        4GB, 6GB, 8GB
# 7          $ 574.90 / € 705.34 / £ 579.95 / ₹ 79,999                 12GB
# 8          $ 289.95 / € 430.00 / £ 368.00 / ₹ 41,560            8GB, 12GB
# 9          $ 250.00 / € 391.90 / £ 364.00 / ₹ 30,999                  8GB
# 10         $ 382.50 / € 310.00 / £ 240.00 / ₹ 20,399       6GB, 8GB, 12GB
# 11         $ 180.49 / € 198.69 / £ 167.51 / ₹ 23,999        4GB, 6GB, 8GB
# 12         $ 129.99 / € 159.00 / £ 129.50 / ₹ 18,999        4GB, 6GB, 8GB
# 13         $ 273.27 / € 424.50 / £ 303.40 / ₹ 65,999            8GB, 12GB
# 14                     $ 123.75 / € 122.00 / £ 99.49        4GB, 6GB, 8GB
# 15            $ 102.00 / € 85.12 / £ 67.00 / ₹ 7,599             4GB, 6GB
# 16         $ 470.00 / € 442.57 / £ 439.00 / ₹ 78,399            8GB, 12GB
# 17         $ 119.00 / € 199.99 / £ 214.99 / ₹ 17,999  4GB, 6GB, 8GB, 12GB
# 18         $ 229.85 / € 330.00 / £ 253.25 / ₹ 46,990                  8GB
# 19                    $ 163.04 / € 234.66 / £ 184.00                  8GB
# 20        $ 539.94 / € 665.00 / £ 699.99 / ₹ 101,999                 12GB
# 21  $ 1,599.99 / € 1,275.00 / £ 1,575.66 / ₹ 174,999           12GB, 16GB
# 22                    $ 169.99 / € 174.99 / £ 101.02        4GB, 6GB, 8GB
# 23                    $ 149.77 / € 198.99 / £ 153.50             6GB, 8GB
# 24                    $ 249.00 / € 267.99 / £ 205.29      8GB, 12GB, 16GB
# 25         $ 119.11 / € 213.00 / £ 174.99 / ₹ 28,999        4GB, 6GB, 8GB
# 26                                               N/A        4GB, 6GB, 8GB
# 27                    $ 899.99 / € 815.00 / £ 803.00                 12GB
# 28                    $ 136.77 / € 256.00 / £ 189.00             6GB, 8GB
# 29             $ 84.99 / € 96.07 / £ 69.70 / ₹ 8,949        3GB, 4GB, 6GB
#
#                 storage
# 0          128GB, 256GB
# 1          256GB, 512GB
# 2          128GB, 256GB
# 3   128GB, 256GB, 512GB
# 4          128GB, 256GB
# 5   128GB, 256GB, 512GB
# 6    64GB, 128GB, 256GB
# 7          256GB, 512GB
# 8   128GB, 256GB, 512GB
# 9   128GB, 256GB, 512GB
# 10         128GB, 256GB
# 11         128GB, 256GB
# 12         128GB, 256GB
# 13  128GB, 256GB, 512GB
# 14         128GB, 256GB
# 15          64GB, 128GB
# 16         256GB, 512GB
# 17         128GB, 256GB
# 18  128GB, 256GB, 512GB
# 19         128GB, 256GB
# 20         256GB, 512GB
# 21         256GB, 512GB
# 22         128GB, 256GB
# 23         128GB, 256GB
# 24  128GB, 256GB, 512GB
# 25         128GB, 256GB
# 26                128GB
# 27         256GB, 512GB
# 28         128GB, 256GB
# 29    32GB, 64GB, 128GB

# %% [markdown]
# # DB- PostgreSQL

# %%
from sqlalchemy import create_engine
import psycopg2

DB_USER = 'postgres'
DB_PASSWORD = 'password'
DB_HOST = 'localhost'
DB_PORT = '5432'
NEW_DB_NAME = 'samsung-scraped'
TABLE_NAME = 'mobile_specs'

try:
    conn = psycopg2.connect(
        database='postgres',
        user=DB_USER,
        password=DB_PASSWORD,
        host=DB_HOST,
        port=DB_PORT
    )
    conn.autocommit = True
    cursor = conn.cursor()

    cursor.execute(f"SELECT 1 FROM pg_database WHERE datname = '{NEW_DB_NAME}'")
    exists = cursor.fetchone()
    if not exists:
        cursor.execute(f"CREATE DATABASE \"{NEW_DB_NAME}\"")
        print(f"Database '{NEW_DB_NAME}' created successfully.")
    else:
        print(f"Database '{NEW_DB_NAME}' already exists.")

    cursor.close()
    conn.close()

except psycopg2.OperationalError as e:
    print(f"Error connecting to PostgreSQL: {e}")
    print("Please check your PostgreSQL server status and credentials (user/password).")
# Out:
# Database 'samsung-scraped' already exists.

# %%
DB_CONNECTION_STRING = f"postgresql+psycopg2://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{NEW_DB_NAME}"

try:
    engine = create_engine(DB_CONNECTION_STRING)
    print("SQLAlchemy Engine created successfully.")

    df.to_sql(
        TABLE_NAME, 
        engine, 
        if_exists='replace', 
        index=False         
    )
    print(f"DataFrame successfully inserted into table '{TABLE_NAME}'.")

except Exception as e:
    print(f"Error during data insertion: {e}")
# Out:
# SQLAlchemy Engine created successfully.
# DataFrame successfully inserted into table 'mobile_specs'.

# %%
sql_query = f"SELECT * FROM {TABLE_NAME} LIMIT 5"

try:
    df_check = pd.read_sql(sql_query, engine)
    
    print(f"\nSuccessfully retrieved data from table '{TABLE_NAME}'.")
    print("\n--- First 5 rows of the new PostgreSQL table ---")
    print(df_check)
    print("\n---------------------------------------------------")
    print(df_check.info())

except Exception as e:
    print(f"Error during verification query: {e}")
# Out:
# Successfully retrieved data from table 'mobile_specs'.
#
# --- First 5 rows of the new PostgreSQL table ---
#                       name                                               link  \
# 0        SamsungGalaxy A56  https://www.gsmarena.com/samsung_galaxy_a56-13...
# 1  SamsungGalaxy S25 Ultra  https://www.gsmarena.com/samsung_galaxy_s25_ul...
# 2        SamsungGalaxy A17  https://www.gsmarena.com/samsung_galaxy_a17_5g...
# 3        SamsungGalaxy S25  https://www.gsmarena.com/samsung_galaxy_s25-13...
# 4        SamsungGalaxy A36  https://www.gsmarena.com/samsung_galaxy_a36-13...
#
#                                 released               display  \
# 0     Available. Released 2025, March 10  6.7 inches, 110.2 cm
# 1  Available. Released 2025, February 03  6.9 inches, 116.9 cm
# 2    Available. Released 2025, August 14  6.7 inches, 110.2 cm
# 3  Available. Released 2025, February 03   6.2 inches, 94.4 cm
# 4     Available. Released 2025, March 10  6.7 inches, 110.2 cm
#
#            battery                                             camera  \
# 0         5000 mAh    50 MP, f/1.8, (wide), 1/1.56", 1.0µm, PDAF, OIS
# 1  Li-Ion 5000 mAh  200 MP, f/1.7, 24mm (wide), 1/1.3", 0.6µm, mul...
# 2         5000 mAh     50 MP, f/1.8, (wide), 1/2.76", 0.64µm, AF, OIS
# 3  Li-Ion 4000 mAh  50 MP, f/1.8, 24mm (wide), 1/1.56", 1.0µm, dua...
# 4         5000 mAh           50 MP, f/1.8, (wide), 1/1.96", PDAF, OIS
#
#                                        price             ram  \
# 0  $ 305.00 / € 290.00 / £ 252.00 / ₹ 32,724  6GB, 8GB, 12GB
# 1  $ 689.94 / € 920.00 / £ 770.00 / ₹ 97,500      12GB, 16GB
# 2  $ 205.00 / € 168.00 / £ 182.00 / ₹ 18,999   4GB, 6GB, 8GB
# 3  $ 457.00 / € 519.00 / £ 479.99 / ₹ 61,350            12GB
# 4  $ 248.00 / € 242.99 / £ 215.00 / ₹ 28,499  6GB, 8GB, 12GB
#
#                storage
# 0         128GB, 256GB
# 1         256GB, 512GB
# 2         128GB, 256GB
# 3  128GB, 256GB, 512GB
# 4         128GB, 256GB
#
# ---------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      5 non-null      object
#  1   link      5 non-null      object
#  2   released  5 non-null      object
#  3   display   5 non-null      object
#  4   battery   5 non-null      object
#  5   camera    5 non-null      object
#  6   price     5 non-null      object
#  7   ram       5 non-null      object
#  8   storage   5 non-null      object
# dtypes: object(9)
# memory usage: 492.0+ bytes
# None

# %% [markdown]
# # Dumping PostGreSQL Table into a .sql File

# %%
import subprocess
import os
DUMP_FILE= "db.sql"
dump_command = [
    'pg_dump',
    '-U', DB_USER,     # Username
    '-h', DB_HOST,     # Host
    '-p', DB_PORT,     # Port
    '-d', NEW_DB_NAME,     # Database name
    '-f', DUMP_FILE,   # Output file path
]

try:
    print(f"Running command: pg_dump -U {DB_USER} -d {NEW_DB_NAME} -f {DUMP_FILE}")
    subprocess.run(dump_command, check=True, capture_output=True, text=True)
    
    print(f"Database dump successful! File created at: {DUMP_FILE}")

except subprocess.CalledProcessError as e:
    print(f"pg_dump failed with error code {e.returncode}")
    print(f"STDERR: {e.stderr}")
    
except FileNotFoundError:
    print("Error: 'pg_dump' command not found. Ensure the PostgreSQL bin directory is in your system's PATH.")
# Out:
# Running command: pg_dump -U postgres -d samsung-scraped -f ../data/raw/db.sql
# Database dump successful! File created at: ../data/raw/db.sql
